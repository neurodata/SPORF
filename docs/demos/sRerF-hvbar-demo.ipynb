# %% [markdown]
# # Structured RerF Demo
#
# Similar to figure 13 [here](https://arxiv.org/pdf/1506.03410v4.pdf) we create a
# distribution of 28x28 pixel images with randomly spaced and sized bars.
#
# In class 0 the bars are oriented horizontally and in class 1 the bars are oriented vertically.
#
# We compare the error-counting estimator $\hat{L}_{n,m}$ for $n \in \{10, 20, \dots, 1000\}$ and $m=10000$ over S-RerF, RerF, and a few other classification algorithms.

# %%
# %matplotlib inline
import math
import pandas as pd
import numpy as np
import time, multiprocessing
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

from rerf.RerF import fastPredict, fastPredictPost, fastRerF
from rerf.rerfClassifier import rerfClassifier

from scipy.stats import bernoulli
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
def genHV(h = 28, w = 28, lambda_ = 10, num_samples = 10, prob = 0.5):
    num_bars = np.random.poisson(lam = lambda_, size = num_samples)

    loc = [np.random.randint(0, h, nbi) for nbi in num_bars]
    
    #cls = bernoulli.rvs(p = prob, size = num_samples)
    #classLabel = [0 for _ in range(int(num_samples / 2))] +\
    #        [1 for _ in range(int(num_samples / 2))]

    # Y = [0,1,0,1,0,1,...]
    classLabel = [0,1] * int(num_samples / 2)

    out = []
    for i in range(num_samples):
        X = np.zeros(h * w).reshape(h, w)
        for j in loc[i]:
            X[j, :] = 1

        out.append(X)
            
    for ci in range(len(classLabel)):
        if classLabel[ci] == 1:
            out[ci] = np.transpose(out[ci])

    #out = np.asarray([outi.flatten() for outi in out])
    out = np.asarray([outi.flatten() for outi in out])

    return out, classLabel

# %%
rng = np.random.RandomState(4)
X_train, Y_train = genHV(num_samples = 1000)
X_test, Y_test = genHV(num_samples = 10000)
plt.subplot(1,2,1)
plt.imshow(X_train[0, :].reshape(28,28))
plt.title("Class 0")
plt.subplot(1,2,2)
plt.imshow(X_train[1, :].reshape(28,28))
plt.title("Class 1")
plt.show()

# %%
## Setup for run
num_runs = 5
names = {"3-Nearest-Neighbors": "blue", "sklearn-RF":"#35B779FF",\
        "ND-RerF-control":"purple", "ND-RF":"#f86000", "RerF": "black", "S-RerF":"#ff0000"}

n_est = 100
ncores = 12

classifiers = [
    KNeighborsClassifier(3, n_jobs=ncores),
    RandomForestClassifier(n_estimators=n_est, max_features=28, n_jobs=ncores),
    rerfClassifier(n_estimators = n_est, projection_matrix = "RerF", 
        max_features = math.ceil(28*2.5*2.5), n_jobs = ncores),
    rerfClassifier(n_estimators = n_est, projection_matrix = "Base", 
        max_features = 28, n_jobs = ncores),
    rerfClassifier(n_estimators = n_est, projection_matrix = "RerF",
        max_features = 28, n_jobs = ncores),
    rerfClassifier(
        projection_matrix="S-RerF", 
        max_features = 28,
        n_estimators=n_est,
        n_jobs=ncores,
        image_height=28, 
        image_width=28, 
        patch_height_max=4,
        patch_width_max=1,
        patch_height_min=4,
        patch_width_min=1,
        )
    ]

# %%
# iterate
## Prep output file:
f = open('s-rerf_runs.csv', 'w+')
f.write("classifier,n,Lhat,trainTime,testTime,iterate\n")
f.flush()

ns = [i for i in range(10, 250, 10)] + [250, 500]+ [X_train.shape[0]]
ns.sort()
ns.reverse()

runList = [(n, clf, iterate) for n in ns\
                             for clf in zip(classifiers, [key for key in names])\
                             for iterate in range(1, num_runs + 1)]

for n, clf, iterate in runList:
        print(f"iterate: {iterate}\t n: {n}\t classifier: {clf[1]}")
        X = X_train[0:n, ::]
        y = Y_train[0:n]

        trainStartTime = time.time()
        clf[0].fit(X, y)
        trainEndTime = time.time()
        trainTime = trainEndTime - trainStartTime

        testStartTime = time.time()
        out = clf[0].predict(X_test)
        testEndTime = time.time()
        testTime = testEndTime - testStartTime

        lhat = np.mean(np.not_equal(out, Y_test).astype(int))


        ####("variable,Lhat,trainTime,testTime,iterate")
        f.write(f"{clf[1]}, {n}, {lhat:2.9f}, {trainTime:2.9f}, {testTime:2.9f}, {iterate}\n")
        f.flush()

f.close()
# Out:
# iterate: 1	 n: 1000	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 1000	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 1000	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 1000	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 1000	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 1000	 classifier: sklearn-RF
# iterate: 2	 n: 1000	 classifier: sklearn-RF
# iterate: 3	 n: 1000	 classifier: sklearn-RF
# iterate: 4	 n: 1000	 classifier: sklearn-RF
# iterate: 5	 n: 1000	 classifier: sklearn-RF
# iterate: 1	 n: 1000	 classifier: ND-RerF-control
# iterate: 2	 n: 1000	 classifier: ND-RerF-control
# iterate: 3	 n: 1000	 classifier: ND-RerF-control
# iterate: 4	 n: 1000	 classifier: ND-RerF-control
# iterate: 5	 n: 1000	 classifier: ND-RerF-control
# iterate: 1	 n: 1000	 classifier: ND-RF
# iterate: 2	 n: 1000	 classifier: ND-RF
# iterate: 3	 n: 1000	 classifier: ND-RF
# iterate: 4	 n: 1000	 classifier: ND-RF
# iterate: 5	 n: 1000	 classifier: ND-RF
# iterate: 1	 n: 1000	 classifier: RerF
# iterate: 2	 n: 1000	 classifier: RerF
# iterate: 3	 n: 1000	 classifier: RerF
# iterate: 4	 n: 1000	 classifier: RerF
# iterate: 5	 n: 1000	 classifier: RerF
# iterate: 1	 n: 1000	 classifier: S-RerF
# iterate: 2	 n: 1000	 classifier: S-RerF
# iterate: 3	 n: 1000	 classifier: S-RerF
# iterate: 4	 n: 1000	 classifier: S-RerF
# iterate: 5	 n: 1000	 classifier: S-RerF
# iterate: 1	 n: 500	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 500	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 500	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 500	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 500	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 500	 classifier: sklearn-RF
# iterate: 2	 n: 500	 classifier: sklearn-RF
# iterate: 3	 n: 500	 classifier: sklearn-RF
# iterate: 4	 n: 500	 classifier: sklearn-RF
# iterate: 5	 n: 500	 classifier: sklearn-RF
# iterate: 1	 n: 500	 classifier: ND-RerF-control
# iterate: 2	 n: 500	 classifier: ND-RerF-control
# iterate: 3	 n: 500	 classifier: ND-RerF-control
# iterate: 4	 n: 500	 classifier: ND-RerF-control
# iterate: 5	 n: 500	 classifier: ND-RerF-control
# iterate: 1	 n: 500	 classifier: ND-RF
# iterate: 2	 n: 500	 classifier: ND-RF
# iterate: 3	 n: 500	 classifier: ND-RF
# iterate: 4	 n: 500	 classifier: ND-RF
# iterate: 5	 n: 500	 classifier: ND-RF
# iterate: 1	 n: 500	 classifier: RerF
# iterate: 2	 n: 500	 classifier: RerF
# iterate: 3	 n: 500	 classifier: RerF
# iterate: 4	 n: 500	 classifier: RerF
# iterate: 5	 n: 500	 classifier: RerF
# iterate: 1	 n: 500	 classifier: S-RerF
# iterate: 2	 n: 500	 classifier: S-RerF
# iterate: 3	 n: 500	 classifier: S-RerF
# iterate: 4	 n: 500	 classifier: S-RerF
# iterate: 5	 n: 500	 classifier: S-RerF
# iterate: 1	 n: 250	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 250	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 250	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 250	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 250	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 250	 classifier: sklearn-RF
# iterate: 2	 n: 250	 classifier: sklearn-RF
# iterate: 3	 n: 250	 classifier: sklearn-RF
# iterate: 4	 n: 250	 classifier: sklearn-RF
# iterate: 5	 n: 250	 classifier: sklearn-RF
# iterate: 1	 n: 250	 classifier: ND-RerF-control
# iterate: 2	 n: 250	 classifier: ND-RerF-control
# iterate: 3	 n: 250	 classifier: ND-RerF-control
# iterate: 4	 n: 250	 classifier: ND-RerF-control
# iterate: 5	 n: 250	 classifier: ND-RerF-control
# iterate: 1	 n: 250	 classifier: ND-RF
# iterate: 2	 n: 250	 classifier: ND-RF
# iterate: 3	 n: 250	 classifier: ND-RF
# iterate: 4	 n: 250	 classifier: ND-RF
# iterate: 5	 n: 250	 classifier: ND-RF
# iterate: 1	 n: 250	 classifier: RerF
# iterate: 2	 n: 250	 classifier: RerF
# iterate: 3	 n: 250	 classifier: RerF
# iterate: 4	 n: 250	 classifier: RerF
# iterate: 5	 n: 250	 classifier: RerF
# iterate: 1	 n: 250	 classifier: S-RerF
# iterate: 2	 n: 250	 classifier: S-RerF
# iterate: 3	 n: 250	 classifier: S-RerF
# iterate: 4	 n: 250	 classifier: S-RerF
# iterate: 5	 n: 250	 classifier: S-RerF
# iterate: 1	 n: 240	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 240	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 240	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 240	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 240	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 240	 classifier: sklearn-RF
# iterate: 2	 n: 240	 classifier: sklearn-RF
# iterate: 3	 n: 240	 classifier: sklearn-RF
# iterate: 4	 n: 240	 classifier: sklearn-RF
# iterate: 5	 n: 240	 classifier: sklearn-RF
# iterate: 1	 n: 240	 classifier: ND-RerF-control
# iterate: 2	 n: 240	 classifier: ND-RerF-control
# iterate: 3	 n: 240	 classifier: ND-RerF-control
# iterate: 4	 n: 240	 classifier: ND-RerF-control
# iterate: 5	 n: 240	 classifier: ND-RerF-control
# iterate: 1	 n: 240	 classifier: ND-RF
# iterate: 2	 n: 240	 classifier: ND-RF
# iterate: 3	 n: 240	 classifier: ND-RF
# iterate: 4	 n: 240	 classifier: ND-RF
# iterate: 5	 n: 240	 classifier: ND-RF
# iterate: 1	 n: 240	 classifier: RerF
# iterate: 2	 n: 240	 classifier: RerF
# iterate: 3	 n: 240	 classifier: RerF
# iterate: 4	 n: 240	 classifier: RerF
# iterate: 5	 n: 240	 classifier: RerF
# iterate: 1	 n: 240	 classifier: S-RerF
# iterate: 2	 n: 240	 classifier: S-RerF
# iterate: 3	 n: 240	 classifier: S-RerF
# iterate: 4	 n: 240	 classifier: S-RerF
# iterate: 5	 n: 240	 classifier: S-RerF
# iterate: 1	 n: 230	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 230	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 230	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 230	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 230	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 230	 classifier: sklearn-RF
# iterate: 2	 n: 230	 classifier: sklearn-RF
# iterate: 3	 n: 230	 classifier: sklearn-RF
# iterate: 4	 n: 230	 classifier: sklearn-RF
# iterate: 5	 n: 230	 classifier: sklearn-RF
# iterate: 1	 n: 230	 classifier: ND-RerF-control
# iterate: 2	 n: 230	 classifier: ND-RerF-control
# iterate: 3	 n: 230	 classifier: ND-RerF-control
# iterate: 4	 n: 230	 classifier: ND-RerF-control
# iterate: 5	 n: 230	 classifier: ND-RerF-control
# iterate: 1	 n: 230	 classifier: ND-RF
# iterate: 2	 n: 230	 classifier: ND-RF
# iterate: 3	 n: 230	 classifier: ND-RF
# iterate: 4	 n: 230	 classifier: ND-RF
# iterate: 5	 n: 230	 classifier: ND-RF
# iterate: 1	 n: 230	 classifier: RerF
# iterate: 2	 n: 230	 classifier: RerF
# iterate: 3	 n: 230	 classifier: RerF
# iterate: 4	 n: 230	 classifier: RerF
# iterate: 5	 n: 230	 classifier: RerF
# iterate: 1	 n: 230	 classifier: S-RerF
# iterate: 2	 n: 230	 classifier: S-RerF
# iterate: 3	 n: 230	 classifier: S-RerF
# iterate: 4	 n: 230	 classifier: S-RerF
# iterate: 5	 n: 230	 classifier: S-RerF
# iterate: 1	 n: 220	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 220	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 220	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 220	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 220	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 220	 classifier: sklearn-RF
# iterate: 2	 n: 220	 classifier: sklearn-RF
# iterate: 3	 n: 220	 classifier: sklearn-RF
# iterate: 4	 n: 220	 classifier: sklearn-RF
# iterate: 5	 n: 220	 classifier: sklearn-RF
# iterate: 1	 n: 220	 classifier: ND-RerF-control
# iterate: 2	 n: 220	 classifier: ND-RerF-control
# iterate: 3	 n: 220	 classifier: ND-RerF-control
# iterate: 4	 n: 220	 classifier: ND-RerF-control
# iterate: 5	 n: 220	 classifier: ND-RerF-control
# iterate: 1	 n: 220	 classifier: ND-RF
# iterate: 2	 n: 220	 classifier: ND-RF
# iterate: 3	 n: 220	 classifier: ND-RF
# iterate: 4	 n: 220	 classifier: ND-RF
# iterate: 5	 n: 220	 classifier: ND-RF
# iterate: 1	 n: 220	 classifier: RerF
# iterate: 2	 n: 220	 classifier: RerF
# iterate: 3	 n: 220	 classifier: RerF
# iterate: 4	 n: 220	 classifier: RerF
# iterate: 5	 n: 220	 classifier: RerF
# iterate: 1	 n: 220	 classifier: S-RerF
# iterate: 2	 n: 220	 classifier: S-RerF
# iterate: 3	 n: 220	 classifier: S-RerF
# iterate: 4	 n: 220	 classifier: S-RerF
# iterate: 5	 n: 220	 classifier: S-RerF
# iterate: 1	 n: 210	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 210	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 210	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 210	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 210	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 210	 classifier: sklearn-RF
# iterate: 2	 n: 210	 classifier: sklearn-RF
# iterate: 3	 n: 210	 classifier: sklearn-RF
# iterate: 4	 n: 210	 classifier: sklearn-RF
# iterate: 5	 n: 210	 classifier: sklearn-RF
# iterate: 1	 n: 210	 classifier: ND-RerF-control
# iterate: 2	 n: 210	 classifier: ND-RerF-control
# iterate: 3	 n: 210	 classifier: ND-RerF-control
# iterate: 4	 n: 210	 classifier: ND-RerF-control
# iterate: 5	 n: 210	 classifier: ND-RerF-control
# iterate: 1	 n: 210	 classifier: ND-RF
# iterate: 2	 n: 210	 classifier: ND-RF
# iterate: 3	 n: 210	 classifier: ND-RF
# iterate: 4	 n: 210	 classifier: ND-RF
# iterate: 5	 n: 210	 classifier: ND-RF
# iterate: 1	 n: 210	 classifier: RerF
# iterate: 2	 n: 210	 classifier: RerF
# iterate: 3	 n: 210	 classifier: RerF
# iterate: 4	 n: 210	 classifier: RerF
# iterate: 5	 n: 210	 classifier: RerF
# iterate: 1	 n: 210	 classifier: S-RerF
# iterate: 2	 n: 210	 classifier: S-RerF
# iterate: 3	 n: 210	 classifier: S-RerF
# iterate: 4	 n: 210	 classifier: S-RerF
# iterate: 5	 n: 210	 classifier: S-RerF
# iterate: 1	 n: 200	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 200	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 200	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 200	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 200	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 200	 classifier: sklearn-RF
# iterate: 2	 n: 200	 classifier: sklearn-RF
# iterate: 3	 n: 200	 classifier: sklearn-RF
# iterate: 4	 n: 200	 classifier: sklearn-RF
# iterate: 5	 n: 200	 classifier: sklearn-RF
# iterate: 1	 n: 200	 classifier: ND-RerF-control
# iterate: 2	 n: 200	 classifier: ND-RerF-control
# iterate: 3	 n: 200	 classifier: ND-RerF-control
# iterate: 4	 n: 200	 classifier: ND-RerF-control
# iterate: 5	 n: 200	 classifier: ND-RerF-control
# iterate: 1	 n: 200	 classifier: ND-RF
# iterate: 2	 n: 200	 classifier: ND-RF
# iterate: 3	 n: 200	 classifier: ND-RF
# iterate: 4	 n: 200	 classifier: ND-RF
# iterate: 5	 n: 200	 classifier: ND-RF
# iterate: 1	 n: 200	 classifier: RerF
# iterate: 2	 n: 200	 classifier: RerF
# iterate: 3	 n: 200	 classifier: RerF
# iterate: 4	 n: 200	 classifier: RerF
# iterate: 5	 n: 200	 classifier: RerF
# iterate: 1	 n: 200	 classifier: S-RerF
# iterate: 2	 n: 200	 classifier: S-RerF
# iterate: 3	 n: 200	 classifier: S-RerF
# iterate: 4	 n: 200	 classifier: S-RerF
# iterate: 5	 n: 200	 classifier: S-RerF
# iterate: 1	 n: 190	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 190	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 190	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 190	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 190	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 190	 classifier: sklearn-RF
# iterate: 2	 n: 190	 classifier: sklearn-RF
# iterate: 3	 n: 190	 classifier: sklearn-RF
# iterate: 4	 n: 190	 classifier: sklearn-RF
# iterate: 5	 n: 190	 classifier: sklearn-RF
# iterate: 1	 n: 190	 classifier: ND-RerF-control
# iterate: 2	 n: 190	 classifier: ND-RerF-control
# iterate: 3	 n: 190	 classifier: ND-RerF-control
# iterate: 4	 n: 190	 classifier: ND-RerF-control
# iterate: 5	 n: 190	 classifier: ND-RerF-control
# iterate: 1	 n: 190	 classifier: ND-RF
# iterate: 2	 n: 190	 classifier: ND-RF
# iterate: 3	 n: 190	 classifier: ND-RF
# iterate: 4	 n: 190	 classifier: ND-RF
# iterate: 5	 n: 190	 classifier: ND-RF
# iterate: 1	 n: 190	 classifier: RerF
# iterate: 2	 n: 190	 classifier: RerF
# iterate: 3	 n: 190	 classifier: RerF
# iterate: 4	 n: 190	 classifier: RerF
# iterate: 5	 n: 190	 classifier: RerF
# iterate: 1	 n: 190	 classifier: S-RerF
# iterate: 2	 n: 190	 classifier: S-RerF
# iterate: 3	 n: 190	 classifier: S-RerF
# iterate: 4	 n: 190	 classifier: S-RerF
# iterate: 5	 n: 190	 classifier: S-RerF
# iterate: 1	 n: 180	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 180	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 180	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 180	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 180	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 180	 classifier: sklearn-RF
# iterate: 2	 n: 180	 classifier: sklearn-RF
# iterate: 3	 n: 180	 classifier: sklearn-RF
# iterate: 4	 n: 180	 classifier: sklearn-RF
# iterate: 5	 n: 180	 classifier: sklearn-RF
# iterate: 1	 n: 180	 classifier: ND-RerF-control
# iterate: 2	 n: 180	 classifier: ND-RerF-control
# iterate: 3	 n: 180	 classifier: ND-RerF-control
# iterate: 4	 n: 180	 classifier: ND-RerF-control
# iterate: 5	 n: 180	 classifier: ND-RerF-control
# iterate: 1	 n: 180	 classifier: ND-RF
# iterate: 2	 n: 180	 classifier: ND-RF
# iterate: 3	 n: 180	 classifier: ND-RF
# iterate: 4	 n: 180	 classifier: ND-RF
# iterate: 5	 n: 180	 classifier: ND-RF
# iterate: 1	 n: 180	 classifier: RerF
# iterate: 2	 n: 180	 classifier: RerF
# iterate: 3	 n: 180	 classifier: RerF
# iterate: 4	 n: 180	 classifier: RerF
# iterate: 5	 n: 180	 classifier: RerF
# iterate: 1	 n: 180	 classifier: S-RerF
# iterate: 2	 n: 180	 classifier: S-RerF
# iterate: 3	 n: 180	 classifier: S-RerF
# iterate: 4	 n: 180	 classifier: S-RerF
# iterate: 5	 n: 180	 classifier: S-RerF
# iterate: 1	 n: 170	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 170	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 170	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 170	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 170	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 170	 classifier: sklearn-RF
# iterate: 2	 n: 170	 classifier: sklearn-RF
# iterate: 3	 n: 170	 classifier: sklearn-RF
# iterate: 4	 n: 170	 classifier: sklearn-RF
# iterate: 5	 n: 170	 classifier: sklearn-RF
# iterate: 1	 n: 170	 classifier: ND-RerF-control
# iterate: 2	 n: 170	 classifier: ND-RerF-control
# iterate: 3	 n: 170	 classifier: ND-RerF-control
# iterate: 4	 n: 170	 classifier: ND-RerF-control
# iterate: 5	 n: 170	 classifier: ND-RerF-control
# iterate: 1	 n: 170	 classifier: ND-RF
# iterate: 2	 n: 170	 classifier: ND-RF
# iterate: 3	 n: 170	 classifier: ND-RF
# iterate: 4	 n: 170	 classifier: ND-RF
# iterate: 5	 n: 170	 classifier: ND-RF
# iterate: 1	 n: 170	 classifier: RerF
# iterate: 2	 n: 170	 classifier: RerF
# iterate: 3	 n: 170	 classifier: RerF
# iterate: 4	 n: 170	 classifier: RerF
# iterate: 5	 n: 170	 classifier: RerF
# iterate: 1	 n: 170	 classifier: S-RerF
# iterate: 2	 n: 170	 classifier: S-RerF
# iterate: 3	 n: 170	 classifier: S-RerF
# iterate: 4	 n: 170	 classifier: S-RerF
# iterate: 5	 n: 170	 classifier: S-RerF
# iterate: 1	 n: 160	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 160	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 160	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 160	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 160	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 160	 classifier: sklearn-RF
# iterate: 2	 n: 160	 classifier: sklearn-RF
# iterate: 3	 n: 160	 classifier: sklearn-RF
# iterate: 4	 n: 160	 classifier: sklearn-RF
# iterate: 5	 n: 160	 classifier: sklearn-RF
# iterate: 1	 n: 160	 classifier: ND-RerF-control
# iterate: 2	 n: 160	 classifier: ND-RerF-control
# iterate: 3	 n: 160	 classifier: ND-RerF-control
# iterate: 4	 n: 160	 classifier: ND-RerF-control
# iterate: 5	 n: 160	 classifier: ND-RerF-control
# iterate: 1	 n: 160	 classifier: ND-RF
# iterate: 2	 n: 160	 classifier: ND-RF
# iterate: 3	 n: 160	 classifier: ND-RF
# iterate: 4	 n: 160	 classifier: ND-RF
# iterate: 5	 n: 160	 classifier: ND-RF
# iterate: 1	 n: 160	 classifier: RerF
# iterate: 2	 n: 160	 classifier: RerF
# iterate: 3	 n: 160	 classifier: RerF
# iterate: 4	 n: 160	 classifier: RerF
# iterate: 5	 n: 160	 classifier: RerF
# iterate: 1	 n: 160	 classifier: S-RerF
# iterate: 2	 n: 160	 classifier: S-RerF
# iterate: 3	 n: 160	 classifier: S-RerF
# iterate: 4	 n: 160	 classifier: S-RerF
# iterate: 5	 n: 160	 classifier: S-RerF
# iterate: 1	 n: 150	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 150	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 150	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 150	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 150	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 150	 classifier: sklearn-RF
# iterate: 2	 n: 150	 classifier: sklearn-RF
# iterate: 3	 n: 150	 classifier: sklearn-RF
# iterate: 4	 n: 150	 classifier: sklearn-RF
# iterate: 5	 n: 150	 classifier: sklearn-RF
# iterate: 1	 n: 150	 classifier: ND-RerF-control
# iterate: 2	 n: 150	 classifier: ND-RerF-control
# iterate: 3	 n: 150	 classifier: ND-RerF-control
# iterate: 4	 n: 150	 classifier: ND-RerF-control
# iterate: 5	 n: 150	 classifier: ND-RerF-control
# iterate: 1	 n: 150	 classifier: ND-RF
# iterate: 2	 n: 150	 classifier: ND-RF
# iterate: 3	 n: 150	 classifier: ND-RF
# iterate: 4	 n: 150	 classifier: ND-RF
# iterate: 5	 n: 150	 classifier: ND-RF
# iterate: 1	 n: 150	 classifier: RerF
# iterate: 2	 n: 150	 classifier: RerF
# iterate: 3	 n: 150	 classifier: RerF
# iterate: 4	 n: 150	 classifier: RerF
# iterate: 5	 n: 150	 classifier: RerF
# iterate: 1	 n: 150	 classifier: S-RerF
# iterate: 2	 n: 150	 classifier: S-RerF
# iterate: 3	 n: 150	 classifier: S-RerF
# iterate: 4	 n: 150	 classifier: S-RerF
# iterate: 5	 n: 150	 classifier: S-RerF
# iterate: 1	 n: 140	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 140	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 140	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 140	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 140	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 140	 classifier: sklearn-RF
# iterate: 2	 n: 140	 classifier: sklearn-RF
# iterate: 3	 n: 140	 classifier: sklearn-RF
# iterate: 4	 n: 140	 classifier: sklearn-RF
# iterate: 5	 n: 140	 classifier: sklearn-RF
# iterate: 1	 n: 140	 classifier: ND-RerF-control
# iterate: 2	 n: 140	 classifier: ND-RerF-control
# iterate: 3	 n: 140	 classifier: ND-RerF-control
# iterate: 4	 n: 140	 classifier: ND-RerF-control
# iterate: 5	 n: 140	 classifier: ND-RerF-control
# iterate: 1	 n: 140	 classifier: ND-RF
# iterate: 2	 n: 140	 classifier: ND-RF
# iterate: 3	 n: 140	 classifier: ND-RF
# iterate: 4	 n: 140	 classifier: ND-RF
# iterate: 5	 n: 140	 classifier: ND-RF
# iterate: 1	 n: 140	 classifier: RerF
# iterate: 2	 n: 140	 classifier: RerF
# iterate: 3	 n: 140	 classifier: RerF
# iterate: 4	 n: 140	 classifier: RerF
# iterate: 5	 n: 140	 classifier: RerF
# iterate: 1	 n: 140	 classifier: S-RerF
# iterate: 2	 n: 140	 classifier: S-RerF
# iterate: 3	 n: 140	 classifier: S-RerF
# iterate: 4	 n: 140	 classifier: S-RerF
# iterate: 5	 n: 140	 classifier: S-RerF
# iterate: 1	 n: 130	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 130	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 130	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 130	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 130	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 130	 classifier: sklearn-RF
# iterate: 2	 n: 130	 classifier: sklearn-RF
# iterate: 3	 n: 130	 classifier: sklearn-RF
# iterate: 4	 n: 130	 classifier: sklearn-RF
# iterate: 5	 n: 130	 classifier: sklearn-RF
# iterate: 1	 n: 130	 classifier: ND-RerF-control
# iterate: 2	 n: 130	 classifier: ND-RerF-control
# iterate: 3	 n: 130	 classifier: ND-RerF-control
# iterate: 4	 n: 130	 classifier: ND-RerF-control
# iterate: 5	 n: 130	 classifier: ND-RerF-control
# iterate: 1	 n: 130	 classifier: ND-RF
# iterate: 2	 n: 130	 classifier: ND-RF
# iterate: 3	 n: 130	 classifier: ND-RF
# iterate: 4	 n: 130	 classifier: ND-RF
# iterate: 5	 n: 130	 classifier: ND-RF
# iterate: 1	 n: 130	 classifier: RerF
# iterate: 2	 n: 130	 classifier: RerF
# iterate: 3	 n: 130	 classifier: RerF
# iterate: 4	 n: 130	 classifier: RerF
# iterate: 5	 n: 130	 classifier: RerF
# iterate: 1	 n: 130	 classifier: S-RerF
# iterate: 2	 n: 130	 classifier: S-RerF
# iterate: 3	 n: 130	 classifier: S-RerF
# iterate: 4	 n: 130	 classifier: S-RerF
# iterate: 5	 n: 130	 classifier: S-RerF
# iterate: 1	 n: 120	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 120	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 120	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 120	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 120	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 120	 classifier: sklearn-RF
# iterate: 2	 n: 120	 classifier: sklearn-RF
# iterate: 3	 n: 120	 classifier: sklearn-RF
# iterate: 4	 n: 120	 classifier: sklearn-RF
# iterate: 5	 n: 120	 classifier: sklearn-RF
# iterate: 1	 n: 120	 classifier: ND-RerF-control
# iterate: 2	 n: 120	 classifier: ND-RerF-control
# iterate: 3	 n: 120	 classifier: ND-RerF-control
# iterate: 4	 n: 120	 classifier: ND-RerF-control
# iterate: 5	 n: 120	 classifier: ND-RerF-control
# iterate: 1	 n: 120	 classifier: ND-RF
# iterate: 2	 n: 120	 classifier: ND-RF
# iterate: 3	 n: 120	 classifier: ND-RF
# iterate: 4	 n: 120	 classifier: ND-RF
# iterate: 5	 n: 120	 classifier: ND-RF
# iterate: 1	 n: 120	 classifier: RerF
# iterate: 2	 n: 120	 classifier: RerF
# iterate: 3	 n: 120	 classifier: RerF
# iterate: 4	 n: 120	 classifier: RerF
# iterate: 5	 n: 120	 classifier: RerF
# iterate: 1	 n: 120	 classifier: S-RerF
# iterate: 2	 n: 120	 classifier: S-RerF
# iterate: 3	 n: 120	 classifier: S-RerF
# iterate: 4	 n: 120	 classifier: S-RerF
# iterate: 5	 n: 120	 classifier: S-RerF
# iterate: 1	 n: 110	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 110	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 110	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 110	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 110	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 110	 classifier: sklearn-RF
# iterate: 2	 n: 110	 classifier: sklearn-RF
# iterate: 3	 n: 110	 classifier: sklearn-RF
# iterate: 4	 n: 110	 classifier: sklearn-RF
# iterate: 5	 n: 110	 classifier: sklearn-RF
# iterate: 1	 n: 110	 classifier: ND-RerF-control
# iterate: 2	 n: 110	 classifier: ND-RerF-control
# iterate: 3	 n: 110	 classifier: ND-RerF-control
# iterate: 4	 n: 110	 classifier: ND-RerF-control
# iterate: 5	 n: 110	 classifier: ND-RerF-control
# iterate: 1	 n: 110	 classifier: ND-RF
# iterate: 2	 n: 110	 classifier: ND-RF
# iterate: 3	 n: 110	 classifier: ND-RF
# iterate: 4	 n: 110	 classifier: ND-RF
# iterate: 5	 n: 110	 classifier: ND-RF
# iterate: 1	 n: 110	 classifier: RerF
# iterate: 2	 n: 110	 classifier: RerF
# iterate: 3	 n: 110	 classifier: RerF
# iterate: 4	 n: 110	 classifier: RerF
# iterate: 5	 n: 110	 classifier: RerF
# iterate: 1	 n: 110	 classifier: S-RerF
# iterate: 2	 n: 110	 classifier: S-RerF
# iterate: 3	 n: 110	 classifier: S-RerF
# iterate: 4	 n: 110	 classifier: S-RerF
# iterate: 5	 n: 110	 classifier: S-RerF
# iterate: 1	 n: 100	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 100	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 100	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 100	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 100	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 100	 classifier: sklearn-RF
# iterate: 2	 n: 100	 classifier: sklearn-RF
# iterate: 3	 n: 100	 classifier: sklearn-RF
# iterate: 4	 n: 100	 classifier: sklearn-RF
# iterate: 5	 n: 100	 classifier: sklearn-RF
# iterate: 1	 n: 100	 classifier: ND-RerF-control
# iterate: 2	 n: 100	 classifier: ND-RerF-control
# iterate: 3	 n: 100	 classifier: ND-RerF-control
# iterate: 4	 n: 100	 classifier: ND-RerF-control
# iterate: 5	 n: 100	 classifier: ND-RerF-control
# iterate: 1	 n: 100	 classifier: ND-RF
# iterate: 2	 n: 100	 classifier: ND-RF
# iterate: 3	 n: 100	 classifier: ND-RF
# iterate: 4	 n: 100	 classifier: ND-RF
# iterate: 5	 n: 100	 classifier: ND-RF
# iterate: 1	 n: 100	 classifier: RerF
# iterate: 2	 n: 100	 classifier: RerF
# iterate: 3	 n: 100	 classifier: RerF
# iterate: 4	 n: 100	 classifier: RerF
# iterate: 5	 n: 100	 classifier: RerF
# iterate: 1	 n: 100	 classifier: S-RerF
# iterate: 2	 n: 100	 classifier: S-RerF
# iterate: 3	 n: 100	 classifier: S-RerF
# iterate: 4	 n: 100	 classifier: S-RerF
# iterate: 5	 n: 100	 classifier: S-RerF
# iterate: 1	 n: 90	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 90	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 90	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 90	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 90	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 90	 classifier: sklearn-RF
# iterate: 2	 n: 90	 classifier: sklearn-RF
# iterate: 3	 n: 90	 classifier: sklearn-RF
# iterate: 4	 n: 90	 classifier: sklearn-RF
# iterate: 5	 n: 90	 classifier: sklearn-RF
# iterate: 1	 n: 90	 classifier: ND-RerF-control
# iterate: 2	 n: 90	 classifier: ND-RerF-control
# iterate: 3	 n: 90	 classifier: ND-RerF-control
# iterate: 4	 n: 90	 classifier: ND-RerF-control
# iterate: 5	 n: 90	 classifier: ND-RerF-control
# iterate: 1	 n: 90	 classifier: ND-RF
# iterate: 2	 n: 90	 classifier: ND-RF
# iterate: 3	 n: 90	 classifier: ND-RF
# iterate: 4	 n: 90	 classifier: ND-RF
# iterate: 5	 n: 90	 classifier: ND-RF
# iterate: 1	 n: 90	 classifier: RerF
# iterate: 2	 n: 90	 classifier: RerF
# iterate: 3	 n: 90	 classifier: RerF
# iterate: 4	 n: 90	 classifier: RerF
# iterate: 5	 n: 90	 classifier: RerF
# iterate: 1	 n: 90	 classifier: S-RerF
# iterate: 2	 n: 90	 classifier: S-RerF
# iterate: 3	 n: 90	 classifier: S-RerF
# iterate: 4	 n: 90	 classifier: S-RerF
# iterate: 5	 n: 90	 classifier: S-RerF
# iterate: 1	 n: 80	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 80	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 80	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 80	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 80	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 80	 classifier: sklearn-RF
# iterate: 2	 n: 80	 classifier: sklearn-RF
# iterate: 3	 n: 80	 classifier: sklearn-RF
# iterate: 4	 n: 80	 classifier: sklearn-RF
# iterate: 5	 n: 80	 classifier: sklearn-RF
# iterate: 1	 n: 80	 classifier: ND-RerF-control
# iterate: 2	 n: 80	 classifier: ND-RerF-control
# iterate: 3	 n: 80	 classifier: ND-RerF-control
# iterate: 4	 n: 80	 classifier: ND-RerF-control
# iterate: 5	 n: 80	 classifier: ND-RerF-control
# iterate: 1	 n: 80	 classifier: ND-RF
# iterate: 2	 n: 80	 classifier: ND-RF
# iterate: 3	 n: 80	 classifier: ND-RF
# iterate: 4	 n: 80	 classifier: ND-RF
# iterate: 5	 n: 80	 classifier: ND-RF
# iterate: 1	 n: 80	 classifier: RerF
# iterate: 2	 n: 80	 classifier: RerF
# iterate: 3	 n: 80	 classifier: RerF
# iterate: 4	 n: 80	 classifier: RerF
# iterate: 5	 n: 80	 classifier: RerF
# iterate: 1	 n: 80	 classifier: S-RerF
# iterate: 2	 n: 80	 classifier: S-RerF
# iterate: 3	 n: 80	 classifier: S-RerF
# iterate: 4	 n: 80	 classifier: S-RerF
# iterate: 5	 n: 80	 classifier: S-RerF
# iterate: 1	 n: 70	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 70	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 70	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 70	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 70	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 70	 classifier: sklearn-RF
# iterate: 2	 n: 70	 classifier: sklearn-RF
# iterate: 3	 n: 70	 classifier: sklearn-RF
# iterate: 4	 n: 70	 classifier: sklearn-RF
# iterate: 5	 n: 70	 classifier: sklearn-RF
# iterate: 1	 n: 70	 classifier: ND-RerF-control
# iterate: 2	 n: 70	 classifier: ND-RerF-control
# iterate: 3	 n: 70	 classifier: ND-RerF-control
# iterate: 4	 n: 70	 classifier: ND-RerF-control
# iterate: 5	 n: 70	 classifier: ND-RerF-control
# iterate: 1	 n: 70	 classifier: ND-RF
# iterate: 2	 n: 70	 classifier: ND-RF
# iterate: 3	 n: 70	 classifier: ND-RF
# iterate: 4	 n: 70	 classifier: ND-RF
# iterate: 5	 n: 70	 classifier: ND-RF
# iterate: 1	 n: 70	 classifier: RerF
# iterate: 2	 n: 70	 classifier: RerF
# iterate: 3	 n: 70	 classifier: RerF
# iterate: 4	 n: 70	 classifier: RerF
# iterate: 5	 n: 70	 classifier: RerF
# iterate: 1	 n: 70	 classifier: S-RerF
# iterate: 2	 n: 70	 classifier: S-RerF
# iterate: 3	 n: 70	 classifier: S-RerF
# iterate: 4	 n: 70	 classifier: S-RerF
# iterate: 5	 n: 70	 classifier: S-RerF
# iterate: 1	 n: 60	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 60	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 60	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 60	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 60	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 60	 classifier: sklearn-RF
# iterate: 2	 n: 60	 classifier: sklearn-RF
# iterate: 3	 n: 60	 classifier: sklearn-RF
# iterate: 4	 n: 60	 classifier: sklearn-RF
# iterate: 5	 n: 60	 classifier: sklearn-RF
# iterate: 1	 n: 60	 classifier: ND-RerF-control
# iterate: 2	 n: 60	 classifier: ND-RerF-control
# iterate: 3	 n: 60	 classifier: ND-RerF-control
# iterate: 4	 n: 60	 classifier: ND-RerF-control
# iterate: 5	 n: 60	 classifier: ND-RerF-control
# iterate: 1	 n: 60	 classifier: ND-RF
# iterate: 2	 n: 60	 classifier: ND-RF
# iterate: 3	 n: 60	 classifier: ND-RF
# iterate: 4	 n: 60	 classifier: ND-RF
# iterate: 5	 n: 60	 classifier: ND-RF
# iterate: 1	 n: 60	 classifier: RerF
# iterate: 2	 n: 60	 classifier: RerF
# iterate: 3	 n: 60	 classifier: RerF
# iterate: 4	 n: 60	 classifier: RerF
# iterate: 5	 n: 60	 classifier: RerF
# iterate: 1	 n: 60	 classifier: S-RerF
# iterate: 2	 n: 60	 classifier: S-RerF
# iterate: 3	 n: 60	 classifier: S-RerF
# iterate: 4	 n: 60	 classifier: S-RerF
# iterate: 5	 n: 60	 classifier: S-RerF
# iterate: 1	 n: 50	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 50	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 50	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 50	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 50	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 50	 classifier: sklearn-RF
# iterate: 2	 n: 50	 classifier: sklearn-RF
# iterate: 3	 n: 50	 classifier: sklearn-RF
# iterate: 4	 n: 50	 classifier: sklearn-RF
# iterate: 5	 n: 50	 classifier: sklearn-RF
# iterate: 1	 n: 50	 classifier: ND-RerF-control
# iterate: 2	 n: 50	 classifier: ND-RerF-control
# iterate: 3	 n: 50	 classifier: ND-RerF-control
# iterate: 4	 n: 50	 classifier: ND-RerF-control
# iterate: 5	 n: 50	 classifier: ND-RerF-control
# iterate: 1	 n: 50	 classifier: ND-RF
# iterate: 2	 n: 50	 classifier: ND-RF
# iterate: 3	 n: 50	 classifier: ND-RF
# iterate: 4	 n: 50	 classifier: ND-RF
# iterate: 5	 n: 50	 classifier: ND-RF
# iterate: 1	 n: 50	 classifier: RerF
# iterate: 2	 n: 50	 classifier: RerF
# iterate: 3	 n: 50	 classifier: RerF
# iterate: 4	 n: 50	 classifier: RerF
# iterate: 5	 n: 50	 classifier: RerF
# iterate: 1	 n: 50	 classifier: S-RerF
# iterate: 2	 n: 50	 classifier: S-RerF
# iterate: 3	 n: 50	 classifier: S-RerF
# iterate: 4	 n: 50	 classifier: S-RerF
# iterate: 5	 n: 50	 classifier: S-RerF
# iterate: 1	 n: 40	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 40	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 40	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 40	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 40	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 40	 classifier: sklearn-RF
# iterate: 2	 n: 40	 classifier: sklearn-RF
# iterate: 3	 n: 40	 classifier: sklearn-RF
# iterate: 4	 n: 40	 classifier: sklearn-RF
# iterate: 5	 n: 40	 classifier: sklearn-RF
# iterate: 1	 n: 40	 classifier: ND-RerF-control
# iterate: 2	 n: 40	 classifier: ND-RerF-control
# iterate: 3	 n: 40	 classifier: ND-RerF-control
# iterate: 4	 n: 40	 classifier: ND-RerF-control
# iterate: 5	 n: 40	 classifier: ND-RerF-control
# iterate: 1	 n: 40	 classifier: ND-RF
# iterate: 2	 n: 40	 classifier: ND-RF
# iterate: 3	 n: 40	 classifier: ND-RF
# iterate: 4	 n: 40	 classifier: ND-RF
# iterate: 5	 n: 40	 classifier: ND-RF
# iterate: 1	 n: 40	 classifier: RerF
# iterate: 2	 n: 40	 classifier: RerF
# iterate: 3	 n: 40	 classifier: RerF
# iterate: 4	 n: 40	 classifier: RerF
# iterate: 5	 n: 40	 classifier: RerF
# iterate: 1	 n: 40	 classifier: S-RerF
# iterate: 2	 n: 40	 classifier: S-RerF
# iterate: 3	 n: 40	 classifier: S-RerF
# iterate: 4	 n: 40	 classifier: S-RerF
# iterate: 5	 n: 40	 classifier: S-RerF
# iterate: 1	 n: 30	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 30	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 30	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 30	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 30	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 30	 classifier: sklearn-RF
# iterate: 2	 n: 30	 classifier: sklearn-RF
# iterate: 3	 n: 30	 classifier: sklearn-RF
# iterate: 4	 n: 30	 classifier: sklearn-RF
# iterate: 5	 n: 30	 classifier: sklearn-RF
# iterate: 1	 n: 30	 classifier: ND-RerF-control
# iterate: 2	 n: 30	 classifier: ND-RerF-control
# iterate: 3	 n: 30	 classifier: ND-RerF-control
# iterate: 4	 n: 30	 classifier: ND-RerF-control
# iterate: 5	 n: 30	 classifier: ND-RerF-control
# iterate: 1	 n: 30	 classifier: ND-RF
# iterate: 2	 n: 30	 classifier: ND-RF
# iterate: 3	 n: 30	 classifier: ND-RF
# iterate: 4	 n: 30	 classifier: ND-RF
# iterate: 5	 n: 30	 classifier: ND-RF
# iterate: 1	 n: 30	 classifier: RerF
# iterate: 2	 n: 30	 classifier: RerF
# iterate: 3	 n: 30	 classifier: RerF
# iterate: 4	 n: 30	 classifier: RerF
# iterate: 5	 n: 30	 classifier: RerF
# iterate: 1	 n: 30	 classifier: S-RerF
# iterate: 2	 n: 30	 classifier: S-RerF
# iterate: 3	 n: 30	 classifier: S-RerF
# iterate: 4	 n: 30	 classifier: S-RerF
# iterate: 5	 n: 30	 classifier: S-RerF
# iterate: 1	 n: 20	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 20	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 20	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 20	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 20	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 20	 classifier: sklearn-RF
# iterate: 2	 n: 20	 classifier: sklearn-RF
# iterate: 3	 n: 20	 classifier: sklearn-RF
# iterate: 4	 n: 20	 classifier: sklearn-RF
# iterate: 5	 n: 20	 classifier: sklearn-RF
# iterate: 1	 n: 20	 classifier: ND-RerF-control
# iterate: 2	 n: 20	 classifier: ND-RerF-control
# iterate: 3	 n: 20	 classifier: ND-RerF-control
# iterate: 4	 n: 20	 classifier: ND-RerF-control
# iterate: 5	 n: 20	 classifier: ND-RerF-control
# iterate: 1	 n: 20	 classifier: ND-RF
# iterate: 2	 n: 20	 classifier: ND-RF
# iterate: 3	 n: 20	 classifier: ND-RF
# iterate: 4	 n: 20	 classifier: ND-RF
# iterate: 5	 n: 20	 classifier: ND-RF
# iterate: 1	 n: 20	 classifier: RerF
# iterate: 2	 n: 20	 classifier: RerF
# iterate: 3	 n: 20	 classifier: RerF
# iterate: 4	 n: 20	 classifier: RerF
# iterate: 5	 n: 20	 classifier: RerF
# iterate: 1	 n: 20	 classifier: S-RerF
# iterate: 2	 n: 20	 classifier: S-RerF
# iterate: 3	 n: 20	 classifier: S-RerF
# iterate: 4	 n: 20	 classifier: S-RerF
# iterate: 5	 n: 20	 classifier: S-RerF
# iterate: 1	 n: 10	 classifier: 3-Nearest-Neighbors
# iterate: 2	 n: 10	 classifier: 3-Nearest-Neighbors
# iterate: 3	 n: 10	 classifier: 3-Nearest-Neighbors
# iterate: 4	 n: 10	 classifier: 3-Nearest-Neighbors
# iterate: 5	 n: 10	 classifier: 3-Nearest-Neighbors
# iterate: 1	 n: 10	 classifier: sklearn-RF
# iterate: 2	 n: 10	 classifier: sklearn-RF
# iterate: 3	 n: 10	 classifier: sklearn-RF
# iterate: 4	 n: 10	 classifier: sklearn-RF
# iterate: 5	 n: 10	 classifier: sklearn-RF
# iterate: 1	 n: 10	 classifier: ND-RerF-control
# iterate: 2	 n: 10	 classifier: ND-RerF-control
# iterate: 3	 n: 10	 classifier: ND-RerF-control
# iterate: 4	 n: 10	 classifier: ND-RerF-control
# iterate: 5	 n: 10	 classifier: ND-RerF-control
# iterate: 1	 n: 10	 classifier: ND-RF
# iterate: 2	 n: 10	 classifier: ND-RF
# iterate: 3	 n: 10	 classifier: ND-RF
# iterate: 4	 n: 10	 classifier: ND-RF
# iterate: 5	 n: 10	 classifier: ND-RF
# iterate: 1	 n: 10	 classifier: RerF
# iterate: 2	 n: 10	 classifier: RerF
# iterate: 3	 n: 10	 classifier: RerF
# iterate: 4	 n: 10	 classifier: RerF
# iterate: 5	 n: 10	 classifier: RerF
# iterate: 1	 n: 10	 classifier: S-RerF
# iterate: 2	 n: 10	 classifier: S-RerF
# iterate: 3	 n: 10	 classifier: S-RerF
# iterate: 4	 n: 10	 classifier: S-RerF
# iterate: 5	 n: 10	 classifier: S-RerF

# %%
dat = pd.read_csv("s-rerf_runs.csv")

d1 = pd.DataFrame(columns = ['classifier', 'n', 'Lhat', 'se', 'color'])

k = 0
for ni in np.unique(dat['n'])[0:10]:
    for cl in np.unique(dat['classifier']):

        tmp = dat[np.logical_and(dat['classifier'] == cl,dat['n'] == ni)][['n', 'Lhat']]

        se = stats.sem(tmp['Lhat'])

        list(tmp.mean())
        d1.loc[k] = [cl] + list(tmp.mean()) + [se] + [names[cl]]
        k += 1

 
matplotlib.rc('figure', figsize=[12,8], dpi = 300)
fig, ax = plt.subplots(figsize = (8,6))

for key, grp in d1.groupby(['classifier']):
    ax = grp.plot(ax=ax, kind='line', x='n', y='Lhat', label=key, \
            c = names[key], yerr='se', alpha =0.65)
    #ax.set_xscale('log', basex=2)
    #ax.set_yscale('log')

plt.legend(loc='best')
plt.ylabel("Lhat_{n,10000}")
plt.show()
