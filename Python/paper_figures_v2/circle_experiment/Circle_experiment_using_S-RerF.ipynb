# %% [markdown]
# # Structured RerF Demo: Circle Experiment
# Similar to Figure 14 in [this paper](https://arxiv.org/pdf/1506.03410v4.pdf), we form a two-class classification problem in which each data point is a discretization of a circle into 100 points. In each class, two non-adjacent sequences of points take on the value one while the rest of the points take on the value zero. In class 0, both sequences are of length five while in class 1 the sequences are of length four and six. Sequences are distributed uniformly and wrap around from the end of the vector to the start if necessary.
#
# We test the performance of S-Rerf and a set of other classification algorithms, training each on samples of sizes $n \in \{50,100,200,400,1000,2000\}$, each containing an equal number of data points from each class. The average 0-1 loss is evaluated for each algorithm for each training size using a single test set of size $m=10000$ with an equal number of data points in each class.

# %%
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
import seaborn as sns

import pickle
import time
from tqdm import tqdm

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

from rerf.rerfClassifier import rerfClassifier

import warnings
warnings.simplefilter('ignore')

# %%
def samp(n1,n2):
    ## Sample objects from each class
    n1,n2 = int(n1),int(n2)
    X1 = np.empty((n1,100))
    Y1 = np.full(n1,0)
    for i in range(n1):        
        cir = np.zeros(100)
        
        s1 = np.random.choice(range(0,100)) # Random Location
        l1 = [j%100 for j in range(s1,s1+5)] # Length 5 vector from s1
        
        exclude_idx = set([j%100 for j in range(s1-5,s1+6)])
        s2 = np.random.choice(list(set(range(0,100)).difference(exclude_idx)))
        l2 = [j%100 for j in set(range(s2,s2+5)).difference(set(l1))]
        
        cir[l1] = 1
        cir[l2] = 1
        
        X1[i] = cir
        
    X2 = np.empty((n2,100))
    Y2 = np.full(n2,1)
    for i in range(n2):        
        cir = np.zeros(100)
        
        s1 = np.random.choice(range(0,100)) # Random location   
        l1 = [j%100 for j in range(s1,s1+4)] # Length 4 vector from s1
        
        exclude_idx = set([j%100 for j in range(s1-6,s1+5)])
        s2 = np.random.choice(list(set(range(0,100)).difference(exclude_idx)))
        l2 = [j%100 for j in set(range(s2,s2+6)).difference(set(l1))]
        
        cir[l1] = 1
        cir[l2] = 1
        
        X2[i] = cir
        
    return((np.vstack([X1,X2]),np.hstack([Y1,Y2])))

# %%
## Generate train and test sets
np.random.seed(1234)
ns = np.array([10,50,100,200,400,1000,2000])
TRAIN_FRAC = 0.5
ns1 = [int(i*TRAIN_FRAC) for i in ns]
ns2 = ns1

X_train, Y_train = np.empty(shape=(0,100)), np.empty(shape=(0))
for n1,n2 in zip(np.append(ns1[0],np.diff(a=ns1)),
                 np.append(ns2[0],np.diff(a=ns2))):
    x, y = samp(n1,n2)
    shuffled_idx = list(range(len(y))); np.random.shuffle(shuffled_idx)
    X_train = np.vstack((X_train, x[shuffled_idx]))
    Y_train = np.hstack((Y_train, y[shuffled_idx]))
    

TEST_SIZE = 10000
X_test, Y_test = samp(TEST_SIZE, TEST_SIZE)

# %%
## Visualize the training data as an image
fig = plt.figure(figsize=(5,5),facecolor='white')
temp = X_train[:50].copy()
temp[np.where(Y_train[:50]==1)[0]] *= 2
plt.imshow(temp)
plt.title("Training sample colored by class, n=50",fontsize=12)
frame1 = plt.gca()
frame1.axes.get_xaxis().set_ticks([])
frame1.axes.get_yaxis().set_ticks([])
plt.tight_layout()
plt.show()

# %%
## Setup for run, define classifiers to train and test
names = {"Log. Reg": "#a6cee3", 
         "Lin. SVM":"#1f78b4", 
         "SVM":"#b2df8a", 
         "kNN": "#33a02c", 
         "RF":"#fb9a99", 
         "MLP":"#fdbf6f", 
         "RerF":"#ff7f00", 
         "S-RerF":"#e31a1c",
         "CNN":"#cab2d6"}
ncores=1
num_runs=1
n_est=100

classifiers = [
    LogisticRegression(random_state=0, n_jobs=ncores, solver='liblinear'),
    LinearSVC(),
    SVC(C=1.0, kernel='rbf', gamma='auto',random_state=0),
    KNeighborsClassifier(3, n_jobs=ncores),
    RandomForestClassifier(n_estimators=n_est, max_features='auto', n_jobs=ncores),
    MLPClassifier(hidden_layer_sizes=(100, ), random_state=0, max_iter=500),
    rerfClassifier(n_estimators = n_est, projection_matrix = "RerF",
                    max_features = 40, n_jobs = ncores),
    rerfClassifier(projection_matrix="S-RerF",
                   max_features=40,
                   n_jobs=ncores,
                    n_estimators=n_est,
                    oob_score=False,
                    random_state=0,
                    image_height=1,
                    image_width=100,
                    patch_height_max=1,
                    patch_height_min=1,
                    patch_width_max=15,
                    patch_width_min=1
                   )
    ]

# %%
# Train each classifier on each data set size, then test
## Prep output file:
f = open('s-rerf_circle_runs_all.csv', 'w+')
f.write("classifier,n,Lhat,trainTime,testTime,iterate\n")
f.flush()

runList = [(n, clf, run) for n in ns\
                       for clf in zip(classifiers, [key for key in names])\
                       for run in range(num_runs)]

for n, clf, iteration in tqdm(runList):
        X = X_train[:n]
        y = Y_train[:n]

        trainStartTime = time.time()
        clf[0].fit(X, y)
        trainEndTime = time.time()
        trainTime = trainEndTime - trainStartTime

        testStartTime = time.time()
        out = clf[0].predict(X_test)
        testEndTime = time.time()
        testTime = testEndTime - testStartTime

        lhat = np.mean(np.not_equal(out, Y_test).astype(int))


        ####("variable,Lhat,trainTime,testTime,iterate")
        f.write(f"{clf[1]}, {n}, {lhat:2.9f}, {trainTime:2.9f}, {testTime:2.9f}, {iteration}\n")
        f.flush()

f.close()
# Out:
# 100%|██████████| 56/56 [06:40<00:00, 30.88s/it]

# %%
## Read output file log and plot
dat = pd.read_csv("s-rerf_circle_runs_all.csv")

#d1 = pd.DataFrame(columns = ['classifier', 'n', 'Lhat', 'se', 'color'])
d1 = pd.DataFrame(columns = ['classifier', 'n', 'Lhat', 'color'])

k = 0
for ni in np.unique(dat['n']):
    for cl in np.unique(dat['classifier']):

        tmp = dat[np.logical_and(dat['classifier'] == cl,dat['n'] == ni)][['n', 'Lhat']]

        se = stats.sem(tmp['Lhat'])

        list(tmp.mean())
        #d1.loc[k] = [cl] + list(tmp.mean()) + [se] + [names[cl]]
        d1.loc[k] = [cl] + list(tmp.mean()) + [names[cl]]
        k += 1

## CNN ADDON
dat2 = pd.read_csv("circle_cnn_results_5runs.csv")

for ni in np.unique(dat2['n']):
    for cl in np.unique(dat2['classifier']):
        if not cl in names.keys():
            continue
            
        tmp = dat2[np.logical_and(dat2['classifier'] == cl,dat2['n'] == ni)][['n', 'Lhat']]
        
        se = stats.sem(tmp['Lhat'])
        
        list(tmp.mean())
        #d1.loc[k] = [cl] + list(tmp.mean()) + [se] + [names[cl]]
        d1.loc[k] = [cl] + list(tmp.mean()) + [names[cl]]
        k += 1

fontsize = 11

sns.set(); sns.set(style="darkgrid", rc={"font.size":fontsize,"axes.titlesize":fontsize,"axes.labelsize":fontsize})        
fig, ax = plt.subplots(figsize = (5,4))

for key in names.keys():
    grp = d1[d1['classifier'] == key] 
    ax = grp.plot(ax=ax, kind='line', x='n', y='Lhat', label=key, \
            c = names[key], alpha =0.65)
    ax.set_xscale('log')

lgd = ax.legend(title='Algorithm', loc='upper left',bbox_to_anchor = (1.04,1), borderaxespad=0, frameon=False)
plt.title('Torus Classification Results')
plt.ylabel('Mean test error')
plt.xlabel('Number of training samples')
plt.tight_layout()
#plt.savefig('./s-rerf_circle_experiment.pdf',format='pdf')
plt.show()

# %% [markdown]
# ## CNN Classification

# %%
import torch
import torch.nn as nn
import torch.utils.data as utils
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

# %%
# Hyperparameters
num_epochs = 100
num_classes = 2
batch_size = 200
learning_rate = 0.001
num_cnn_runs = 5

# %%
tensor_x = torch.from_numpy(np.reshape(X_test,(X_test.shape[0],1,X_test.shape[1]))).float()
tensor_y = torch.from_numpy(np.asarray(Y_test)).long()

test_tensor = utils.TensorDataset(tensor_x,tensor_y) # create your datset
test_loader = DataLoader(dataset=test_tensor, batch_size=batch_size, shuffle=False)

# %%
# Convolutional neural network (two convolutional layers)
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=6, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2))
        self.layer2 = nn.Sequential(
            nn.Conv1d(32, 64, kernel_size=6, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout()
        self.fc1 = nn.Linear(21 * 64, 200)
        self.fc2 = nn.Linear(200, 2)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
def cnn_learn(n, model):
    ## Data loader
    batch_size = int(n)
    
    X = X_train[0:n, ::]
    Y = Y_train[0:n]
    
    tensor_x = torch.from_numpy(np.reshape(X,(X.shape[0],1,X.shape[1]))).float()
    tensor_y = torch.from_numpy(np.asanyarray(Y)).long()

    train_tensor = utils.TensorDataset(tensor_x,tensor_y) # create your datset

    train_loader = DataLoader(dataset=train_tensor, batch_size=batch_size, shuffle=True)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    # Train the model
    trainStartTime = time.time()
    
    total_step = len(train_loader)
    loss_list = []
    acc_list = []
    prior_loss = []
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            #images = images.float(); labels = labels.long()
            # Run the forward pass
            outputs = model(images.float())
            loss = criterion(outputs, labels.long())
            loss_list.append(loss.item())

            # Backprop and perform Adam optimisation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track the accuracy
            total = labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct = (predicted == labels).sum().item()
            acc_list.append(correct / total)

            if ((i + 1) % 1 == 0) and ((epoch + 1) % 5 == 0):
                print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                      .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(),
                              (correct / total) * 100))
        if epoch > 10:
            if loss.item() < 0.1 and stats.sem(prior_loss[-5:]) < 0.001:
                break
        prior_loss.append(loss.item())
    
    trainEndTime = time.time()
    trainTime = trainEndTime - trainStartTime
    
    # Test the model
    testStartTime = time.time()
    
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
        testEndTime = time.time()
        testTime = testEndTime - testStartTime
        print('Test Accuracy of the model on the test images: {} %'.format((correct / total) * 100))
        
        lhat = 1- correct / total

        ####("variable,Lhat,trainTime,testTime,iterate")
        clf = "CNN"; iterate = 1
        
        return((clf,n,lhat,trainTime,testTime,iterate))

# %%
## Log output
np.random.seed(1234)

write_path = 'circle_cnn_results_5runs.csv'

with open(write_path, 'w') as f:
    f.write("classifier,n,Lhat,trainTime,testTime,iterate\n")
    
runList = [(n, iterate) for n in ns\
                        for iterate in range(1, num_cnn_runs + 1)]

for n, iterate in runList:
    print(f"Size={n}, Iterate {iterate}")
    model = ConvNet()
    clf,n,lhat,trainTime,testTime,iterate = cnn_learn(n, model)
    
    with open(write_path, 'a') as f:
        f.write(f"{clf}, {n}, {lhat:2.9f}, {trainTime:2.9f}, {testTime:2.9f}, {iterate}\n")
# Out:
# Size=10, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.5595, Accuracy: 80.00%
# Epoch [10/100], Step [1/1], Loss: 0.3546, Accuracy: 90.00%
# Epoch [15/100], Step [1/1], Loss: 0.1605, Accuracy: 100.00%
# Epoch [20/100], Step [1/1], Loss: 0.1502, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0376, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0108, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0141, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0264, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0049, Accuracy: 100.00%
# Epoch [50/100], Step [1/1], Loss: 0.0027, Accuracy: 100.00%
# Epoch [55/100], Step [1/1], Loss: 0.0008, Accuracy: 100.00%
# Epoch [60/100], Step [1/1], Loss: 0.0409, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 49.68 %
# Size=10, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.5429, Accuracy: 90.00%
# Epoch [10/100], Step [1/1], Loss: 0.3304, Accuracy: 90.00%
# Epoch [15/100], Step [1/1], Loss: 0.1292, Accuracy: 100.00%
# Epoch [20/100], Step [1/1], Loss: 0.1212, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0065, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0165, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0190, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0062, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0038, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 49.76 %
# Size=10, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.5106, Accuracy: 100.00%
# Epoch [10/100], Step [1/1], Loss: 0.2915, Accuracy: 90.00%
# Epoch [15/100], Step [1/1], Loss: 0.0959, Accuracy: 100.00%
# Epoch [20/100], Step [1/1], Loss: 0.0808, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0248, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0171, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0125, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0043, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0029, Accuracy: 100.00%
# Epoch [50/100], Step [1/1], Loss: 0.0019, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 50.17 %
# Size=10, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.5313, Accuracy: 100.00%
# Epoch [10/100], Step [1/1], Loss: 0.2839, Accuracy: 90.00%
# Epoch [15/100], Step [1/1], Loss: 0.1525, Accuracy: 100.00%
# Epoch [20/100], Step [1/1], Loss: 0.0843, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.1165, Accuracy: 90.00%
# Epoch [30/100], Step [1/1], Loss: 0.0331, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0037, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0080, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0167, Accuracy: 100.00%
# Epoch [50/100], Step [1/1], Loss: 0.0079, Accuracy: 100.00%
# Epoch [55/100], Step [1/1], Loss: 0.0018, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 49.995 %
# Size=10, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.5810, Accuracy: 90.00%
# Epoch [10/100], Step [1/1], Loss: 0.3776, Accuracy: 90.00%
# Epoch [15/100], Step [1/1], Loss: 0.1755, Accuracy: 90.00%
# Epoch [20/100], Step [1/1], Loss: 0.0810, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0425, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0051, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0058, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0041, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 49.769999999999996 %
# Size=50, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.6463, Accuracy: 68.00%
# Epoch [10/100], Step [1/1], Loss: 0.6125, Accuracy: 62.00%
# Epoch [15/100], Step [1/1], Loss: 0.5912, Accuracy: 70.00%
# Epoch [20/100], Step [1/1], Loss: 0.5217, Accuracy: 74.00%
# Epoch [25/100], Step [1/1], Loss: 0.4307, Accuracy: 80.00%
# Epoch [30/100], Step [1/1], Loss: 0.3927, Accuracy: 90.00%
# Epoch [35/100], Step [1/1], Loss: 0.3310, Accuracy: 90.00%
# Epoch [40/100], Step [1/1], Loss: 0.2423, Accuracy: 88.00%
# Epoch [45/100], Step [1/1], Loss: 0.1712, Accuracy: 96.00%
# Epoch [50/100], Step [1/1], Loss: 0.1537, Accuracy: 92.00%
# Epoch [55/100], Step [1/1], Loss: 0.1492, Accuracy: 94.00%
# Epoch [60/100], Step [1/1], Loss: 0.0904, Accuracy: 98.00%
# Epoch [65/100], Step [1/1], Loss: 0.0760, Accuracy: 100.00%
# Epoch [70/100], Step [1/1], Loss: 0.0960, Accuracy: 98.00%
# Epoch [75/100], Step [1/1], Loss: 0.0233, Accuracy: 100.00%
# Epoch [80/100], Step [1/1], Loss: 0.0467, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0431, Accuracy: 100.00%
# Epoch [90/100], Step [1/1], Loss: 0.0289, Accuracy: 100.00%
# Epoch [95/100], Step [1/1], Loss: 0.0220, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.0139, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 52.55499999999999 %
# Size=50, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.6587, Accuracy: 62.00%
# Epoch [10/100], Step [1/1], Loss: 0.6109, Accuracy: 68.00%
# Epoch [15/100], Step [1/1], Loss: 0.5789, Accuracy: 68.00%
# Epoch [20/100], Step [1/1], Loss: 0.5416, Accuracy: 80.00%
# Epoch [25/100], Step [1/1], Loss: 0.5011, Accuracy: 78.00%
# Epoch [30/100], Step [1/1], Loss: 0.5059, Accuracy: 76.00%
# Epoch [35/100], Step [1/1], Loss: 0.4148, Accuracy: 86.00%
# Epoch [40/100], Step [1/1], Loss: 0.2714, Accuracy: 90.00%
# Epoch [45/100], Step [1/1], Loss: 0.3219, Accuracy: 86.00%
# Epoch [50/100], Step [1/1], Loss: 0.2159, Accuracy: 96.00%
# Epoch [55/100], Step [1/1], Loss: 0.1868, Accuracy: 92.00%
# Epoch [60/100], Step [1/1], Loss: 0.1411, Accuracy: 96.00%
# Epoch [65/100], Step [1/1], Loss: 0.1506, Accuracy: 96.00%
# Epoch [70/100], Step [1/1], Loss: 0.1027, Accuracy: 98.00%
# Epoch [75/100], Step [1/1], Loss: 0.0587, Accuracy: 100.00%
# Epoch [80/100], Step [1/1], Loss: 0.1096, Accuracy: 96.00%
# Epoch [85/100], Step [1/1], Loss: 0.0877, Accuracy: 98.00%
# Epoch [90/100], Step [1/1], Loss: 0.0521, Accuracy: 98.00%
# Epoch [95/100], Step [1/1], Loss: 0.0825, Accuracy: 96.00%
# Epoch [100/100], Step [1/1], Loss: 0.0395, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 52.745 %
# Size=50, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6526, Accuracy: 72.00%
# Epoch [10/100], Step [1/1], Loss: 0.5665, Accuracy: 76.00%
# Epoch [15/100], Step [1/1], Loss: 0.5249, Accuracy: 78.00%
# Epoch [20/100], Step [1/1], Loss: 0.5355, Accuracy: 78.00%
# Epoch [25/100], Step [1/1], Loss: 0.4776, Accuracy: 78.00%
# Epoch [30/100], Step [1/1], Loss: 0.3477, Accuracy: 82.00%
# Epoch [35/100], Step [1/1], Loss: 0.2696, Accuracy: 94.00%
# Epoch [40/100], Step [1/1], Loss: 0.2539, Accuracy: 92.00%
# Epoch [45/100], Step [1/1], Loss: 0.1500, Accuracy: 98.00%
# Epoch [50/100], Step [1/1], Loss: 0.2043, Accuracy: 92.00%
# Epoch [55/100], Step [1/1], Loss: 0.0858, Accuracy: 100.00%
# Epoch [60/100], Step [1/1], Loss: 0.1672, Accuracy: 94.00%
# Epoch [65/100], Step [1/1], Loss: 0.0711, Accuracy: 100.00%
# Epoch [70/100], Step [1/1], Loss: 0.0912, Accuracy: 96.00%
# Epoch [75/100], Step [1/1], Loss: 0.0908, Accuracy: 98.00%
# Epoch [80/100], Step [1/1], Loss: 0.0586, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0384, Accuracy: 100.00%
# Epoch [90/100], Step [1/1], Loss: 0.0505, Accuracy: 98.00%
# Epoch [95/100], Step [1/1], Loss: 0.0139, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.0148, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 57.84 %
# Size=50, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.6504, Accuracy: 72.00%
# Epoch [10/100], Step [1/1], Loss: 0.6167, Accuracy: 70.00%
# Epoch [15/100], Step [1/1], Loss: 0.5770, Accuracy: 76.00%
# Epoch [20/100], Step [1/1], Loss: 0.5549, Accuracy: 74.00%
# Epoch [25/100], Step [1/1], Loss: 0.4386, Accuracy: 78.00%
# Epoch [30/100], Step [1/1], Loss: 0.4269, Accuracy: 80.00%
# Epoch [35/100], Step [1/1], Loss: 0.3634, Accuracy: 88.00%
# Epoch [40/100], Step [1/1], Loss: 0.2794, Accuracy: 94.00%
# Epoch [45/100], Step [1/1], Loss: 0.1966, Accuracy: 94.00%
# Epoch [50/100], Step [1/1], Loss: 0.1816, Accuracy: 98.00%
# Epoch [55/100], Step [1/1], Loss: 0.0770, Accuracy: 100.00%
# Epoch [60/100], Step [1/1], Loss: 0.1476, Accuracy: 96.00%
# Epoch [65/100], Step [1/1], Loss: 0.0881, Accuracy: 98.00%
# Epoch [70/100], Step [1/1], Loss: 0.0702, Accuracy: 100.00%
# Epoch [75/100], Step [1/1], Loss: 0.0429, Accuracy: 100.00%
# Epoch [80/100], Step [1/1], Loss: 0.0573, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0253, Accuracy: 100.00%
# Epoch [90/100], Step [1/1], Loss: 0.0435, Accuracy: 98.00%
# Epoch [95/100], Step [1/1], Loss: 0.0349, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.0171, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 51.615 %
# Size=50, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6369, Accuracy: 70.00%
# Epoch [10/100], Step [1/1], Loss: 0.5852, Accuracy: 68.00%
# Epoch [15/100], Step [1/1], Loss: 0.5196, Accuracy: 76.00%
# Epoch [20/100], Step [1/1], Loss: 0.4744, Accuracy: 84.00%
# Epoch [25/100], Step [1/1], Loss: 0.4600, Accuracy: 74.00%
# Epoch [30/100], Step [1/1], Loss: 0.4771, Accuracy: 74.00%
# Epoch [35/100], Step [1/1], Loss: 0.3188, Accuracy: 90.00%
# Epoch [40/100], Step [1/1], Loss: 0.2920, Accuracy: 88.00%
# Epoch [45/100], Step [1/1], Loss: 0.2970, Accuracy: 82.00%
# Epoch [50/100], Step [1/1], Loss: 0.2790, Accuracy: 90.00%
# Epoch [55/100], Step [1/1], Loss: 0.1418, Accuracy: 100.00%
# Epoch [60/100], Step [1/1], Loss: 0.1371, Accuracy: 94.00%
# Epoch [65/100], Step [1/1], Loss: 0.1636, Accuracy: 96.00%
# Epoch [70/100], Step [1/1], Loss: 0.0973, Accuracy: 100.00%
# Epoch [75/100], Step [1/1], Loss: 0.1280, Accuracy: 94.00%
# Epoch [80/100], Step [1/1], Loss: 0.0521, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.1529, Accuracy: 94.00%
# Epoch [90/100], Step [1/1], Loss: 0.0405, Accuracy: 100.00%
# Epoch [95/100], Step [1/1], Loss: 0.0723, Accuracy: 96.00%
# Epoch [100/100], Step [1/1], Loss: 0.0250, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 53.815000000000005 %
# Size=100, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.6595, Accuracy: 60.00%
# Epoch [10/100], Step [1/1], Loss: 0.6230, Accuracy: 65.00%
# Epoch [15/100], Step [1/1], Loss: 0.6164, Accuracy: 67.00%
# Epoch [20/100], Step [1/1], Loss: 0.5876, Accuracy: 70.00%
# Epoch [25/100], Step [1/1], Loss: 0.5506, Accuracy: 73.00%
# Epoch [30/100], Step [1/1], Loss: 0.5376, Accuracy: 74.00%
# Epoch [35/100], Step [1/1], Loss: 0.5123, Accuracy: 74.00%
# Epoch [40/100], Step [1/1], Loss: 0.4782, Accuracy: 75.00%
# Epoch [45/100], Step [1/1], Loss: 0.4880, Accuracy: 77.00%
# Epoch [50/100], Step [1/1], Loss: 0.4871, Accuracy: 74.00%
# Epoch [55/100], Step [1/1], Loss: 0.3661, Accuracy: 83.00%
# Epoch [60/100], Step [1/1], Loss: 0.3198, Accuracy: 86.00%
# Epoch [65/100], Step [1/1], Loss: 0.3354, Accuracy: 88.00%
# Epoch [70/100], Step [1/1], Loss: 0.2459, Accuracy: 92.00%
# Epoch [75/100], Step [1/1], Loss: 0.2154, Accuracy: 93.00%
# Epoch [80/100], Step [1/1], Loss: 0.1897, Accuracy: 93.00%
# Epoch [85/100], Step [1/1], Loss: 0.1375, Accuracy: 94.00%
# Epoch [90/100], Step [1/1], Loss: 0.1492, Accuracy: 96.00%
# Epoch [95/100], Step [1/1], Loss: 0.0759, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.1509, Accuracy: 96.00%
# Test Accuracy of the model on the test images: 62.214999999999996 %
# Size=100, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.6370, Accuracy: 62.00%
# Epoch [10/100], Step [1/1], Loss: 0.6152, Accuracy: 63.00%
# Epoch [15/100], Step [1/1], Loss: 0.5684, Accuracy: 71.00%
# Epoch [20/100], Step [1/1], Loss: 0.5349, Accuracy: 78.00%
# Epoch [25/100], Step [1/1], Loss: 0.5365, Accuracy: 71.00%
# Epoch [30/100], Step [1/1], Loss: 0.4755, Accuracy: 81.00%
# Epoch [35/100], Step [1/1], Loss: 0.4524, Accuracy: 81.00%
# Epoch [40/100], Step [1/1], Loss: 0.4140, Accuracy: 82.00%
# Epoch [45/100], Step [1/1], Loss: 0.3269, Accuracy: 86.00%
# Epoch [50/100], Step [1/1], Loss: 0.2683, Accuracy: 87.00%
# Epoch [55/100], Step [1/1], Loss: 0.2906, Accuracy: 86.00%
# Epoch [60/100], Step [1/1], Loss: 0.2076, Accuracy: 92.00%
# Epoch [65/100], Step [1/1], Loss: 0.1735, Accuracy: 95.00%
# Epoch [70/100], Step [1/1], Loss: 0.1307, Accuracy: 97.00%
# Epoch [75/100], Step [1/1], Loss: 0.0962, Accuracy: 97.00%
# Epoch [80/100], Step [1/1], Loss: 0.0538, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0499, Accuracy: 99.00%
# Epoch [90/100], Step [1/1], Loss: 0.0446, Accuracy: 100.00%
# Epoch [95/100], Step [1/1], Loss: 0.0595, Accuracy: 98.00%
# Epoch [100/100], Step [1/1], Loss: 0.0365, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 79.07499999999999 %
# Size=100, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6403, Accuracy: 65.00%
# Epoch [10/100], Step [1/1], Loss: 0.6086, Accuracy: 69.00%
# Epoch [15/100], Step [1/1], Loss: 0.5897, Accuracy: 68.00%
# Epoch [20/100], Step [1/1], Loss: 0.5362, Accuracy: 74.00%
# Epoch [25/100], Step [1/1], Loss: 0.5077, Accuracy: 75.00%
# Epoch [30/100], Step [1/1], Loss: 0.4540, Accuracy: 76.00%
# Epoch [35/100], Step [1/1], Loss: 0.4615, Accuracy: 80.00%
# Epoch [40/100], Step [1/1], Loss: 0.4125, Accuracy: 82.00%
# Epoch [45/100], Step [1/1], Loss: 0.3483, Accuracy: 84.00%
# Epoch [50/100], Step [1/1], Loss: 0.2819, Accuracy: 88.00%
# Epoch [55/100], Step [1/1], Loss: 0.2479, Accuracy: 90.00%
# Epoch [60/100], Step [1/1], Loss: 0.2217, Accuracy: 92.00%
# Epoch [65/100], Step [1/1], Loss: 0.1901, Accuracy: 94.00%
# Epoch [70/100], Step [1/1], Loss: 0.1153, Accuracy: 98.00%
# Epoch [75/100], Step [1/1], Loss: 0.1167, Accuracy: 97.00%
# Epoch [80/100], Step [1/1], Loss: 0.0692, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0528, Accuracy: 98.00%
# Epoch [90/100], Step [1/1], Loss: 0.0481, Accuracy: 100.00%
# Epoch [95/100], Step [1/1], Loss: 0.0302, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.0296, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 79.00500000000001 %
# Size=100, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.6295, Accuracy: 65.00%
# Epoch [10/100], Step [1/1], Loss: 0.6057, Accuracy: 66.00%
# Epoch [15/100], Step [1/1], Loss: 0.5708, Accuracy: 70.00%
# Epoch [20/100], Step [1/1], Loss: 0.5634, Accuracy: 73.00%
# Epoch [25/100], Step [1/1], Loss: 0.4907, Accuracy: 77.00%
# Epoch [30/100], Step [1/1], Loss: 0.5011, Accuracy: 80.00%
# Epoch [35/100], Step [1/1], Loss: 0.4487, Accuracy: 81.00%
# Epoch [40/100], Step [1/1], Loss: 0.3941, Accuracy: 81.00%
# Epoch [45/100], Step [1/1], Loss: 0.3200, Accuracy: 84.00%
# Epoch [50/100], Step [1/1], Loss: 0.3012, Accuracy: 88.00%
# Epoch [55/100], Step [1/1], Loss: 0.2479, Accuracy: 93.00%
# Epoch [60/100], Step [1/1], Loss: 0.2357, Accuracy: 89.00%
# Epoch [65/100], Step [1/1], Loss: 0.1883, Accuracy: 93.00%
# Epoch [70/100], Step [1/1], Loss: 0.1295, Accuracy: 98.00%
# Epoch [75/100], Step [1/1], Loss: 0.0904, Accuracy: 98.00%
# Epoch [80/100], Step [1/1], Loss: 0.0663, Accuracy: 99.00%
# Epoch [85/100], Step [1/1], Loss: 0.0566, Accuracy: 97.00%
# Epoch [90/100], Step [1/1], Loss: 0.0544, Accuracy: 98.00%
# Epoch [95/100], Step [1/1], Loss: 0.0317, Accuracy: 99.00%
# Epoch [100/100], Step [1/1], Loss: 0.0223, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 77.41 %
# Size=100, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6257, Accuracy: 71.00%
# Epoch [10/100], Step [1/1], Loss: 0.6260, Accuracy: 66.00%
# Epoch [15/100], Step [1/1], Loss: 0.5654, Accuracy: 71.00%
# Epoch [20/100], Step [1/1], Loss: 0.5400, Accuracy: 72.00%
# Epoch [25/100], Step [1/1], Loss: 0.5084, Accuracy: 78.00%
# Epoch [30/100], Step [1/1], Loss: 0.4530, Accuracy: 79.00%
# Epoch [35/100], Step [1/1], Loss: 0.4074, Accuracy: 82.00%
# Epoch [40/100], Step [1/1], Loss: 0.3659, Accuracy: 85.00%
# Epoch [45/100], Step [1/1], Loss: 0.2544, Accuracy: 90.00%
# Epoch [50/100], Step [1/1], Loss: 0.2354, Accuracy: 89.00%
# Epoch [55/100], Step [1/1], Loss: 0.2127, Accuracy: 91.00%
# Epoch [60/100], Step [1/1], Loss: 0.2015, Accuracy: 92.00%
# Epoch [65/100], Step [1/1], Loss: 0.1119, Accuracy: 97.00%
# Epoch [70/100], Step [1/1], Loss: 0.1094, Accuracy: 98.00%
# Epoch [75/100], Step [1/1], Loss: 0.0826, Accuracy: 98.00%
# Epoch [80/100], Step [1/1], Loss: 0.0712, Accuracy: 99.00%
# Epoch [85/100], Step [1/1], Loss: 0.0527, Accuracy: 98.00%
# Epoch [90/100], Step [1/1], Loss: 0.0334, Accuracy: 99.00%
# Epoch [95/100], Step [1/1], Loss: 0.0552, Accuracy: 99.00%
# Epoch [100/100], Step [1/1], Loss: 0.0391, Accuracy: 99.00%
# Test Accuracy of the model on the test images: 74.76 %
# Size=200, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.6652, Accuracy: 62.50%
# Epoch [10/100], Step [1/1], Loss: 0.6323, Accuracy: 61.50%
# Epoch [15/100], Step [1/1], Loss: 0.6168, Accuracy: 65.50%
# Epoch [20/100], Step [1/1], Loss: 0.5968, Accuracy: 69.00%
# Epoch [25/100], Step [1/1], Loss: 0.5684, Accuracy: 74.00%
# Epoch [30/100], Step [1/1], Loss: 0.5173, Accuracy: 78.50%
# Epoch [35/100], Step [1/1], Loss: 0.4499, Accuracy: 81.00%
# Epoch [40/100], Step [1/1], Loss: 0.3875, Accuracy: 84.00%
# Epoch [45/100], Step [1/1], Loss: 0.3146, Accuracy: 89.00%
# Epoch [50/100], Step [1/1], Loss: 0.2303, Accuracy: 95.00%
# Epoch [55/100], Step [1/1], Loss: 0.1321, Accuracy: 98.00%
# Epoch [60/100], Step [1/1], Loss: 0.0973, Accuracy: 98.50%
# Epoch [65/100], Step [1/1], Loss: 0.0565, Accuracy: 99.50%
# Epoch [70/100], Step [1/1], Loss: 0.0392, Accuracy: 100.00%
# Epoch [75/100], Step [1/1], Loss: 0.0248, Accuracy: 100.00%
# Epoch [80/100], Step [1/1], Loss: 0.0207, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0192, Accuracy: 100.00%
# Epoch [90/100], Step [1/1], Loss: 0.0132, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 99.72 %
# Size=200, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.6454, Accuracy: 58.50%
# Epoch [10/100], Step [1/1], Loss: 0.6279, Accuracy: 65.00%
# Epoch [15/100], Step [1/1], Loss: 0.6057, Accuracy: 69.50%
# Epoch [20/100], Step [1/1], Loss: 0.6009, Accuracy: 67.00%
# Epoch [25/100], Step [1/1], Loss: 0.5684, Accuracy: 68.50%
# Epoch [30/100], Step [1/1], Loss: 0.5498, Accuracy: 71.00%
# Epoch [35/100], Step [1/1], Loss: 0.4761, Accuracy: 78.50%
# Epoch [40/100], Step [1/1], Loss: 0.4251, Accuracy: 84.50%
# Epoch [45/100], Step [1/1], Loss: 0.3394, Accuracy: 87.50%
# Epoch [50/100], Step [1/1], Loss: 0.3007, Accuracy: 90.50%
# Epoch [55/100], Step [1/1], Loss: 0.2312, Accuracy: 93.00%
# Epoch [60/100], Step [1/1], Loss: 0.1824, Accuracy: 94.00%
# Epoch [65/100], Step [1/1], Loss: 0.1134, Accuracy: 97.50%
# Epoch [70/100], Step [1/1], Loss: 0.0590, Accuracy: 99.50%
# Epoch [75/100], Step [1/1], Loss: 0.0482, Accuracy: 99.50%
# Epoch [80/100], Step [1/1], Loss: 0.0382, Accuracy: 99.50%
# Epoch [85/100], Step [1/1], Loss: 0.0310, Accuracy: 100.00%
# Epoch [90/100], Step [1/1], Loss: 0.0267, Accuracy: 99.50%
# Epoch [95/100], Step [1/1], Loss: 0.0213, Accuracy: 99.50%
# Epoch [100/100], Step [1/1], Loss: 0.0205, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 98.32 %
# Size=200, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6554, Accuracy: 60.50%
# Epoch [10/100], Step [1/1], Loss: 0.6367, Accuracy: 64.50%
# Epoch [15/100], Step [1/1], Loss: 0.6114, Accuracy: 66.50%
# Epoch [20/100], Step [1/1], Loss: 0.6030, Accuracy: 68.50%
# Epoch [25/100], Step [1/1], Loss: 0.5821, Accuracy: 65.50%
# Epoch [30/100], Step [1/1], Loss: 0.5673, Accuracy: 68.50%
# Epoch [35/100], Step [1/1], Loss: 0.5421, Accuracy: 73.50%
# Epoch [40/100], Step [1/1], Loss: 0.5028, Accuracy: 77.00%
# Epoch [45/100], Step [1/1], Loss: 0.4426, Accuracy: 81.50%
# Epoch [50/100], Step [1/1], Loss: 0.3406, Accuracy: 88.00%
# Epoch [55/100], Step [1/1], Loss: 0.3050, Accuracy: 91.00%
# Epoch [60/100], Step [1/1], Loss: 0.2262, Accuracy: 93.00%
# Epoch [65/100], Step [1/1], Loss: 0.1607, Accuracy: 95.00%
# Epoch [70/100], Step [1/1], Loss: 0.1243, Accuracy: 98.50%
# Epoch [75/100], Step [1/1], Loss: 0.0798, Accuracy: 99.00%
# Epoch [80/100], Step [1/1], Loss: 0.0532, Accuracy: 99.50%
# Epoch [85/100], Step [1/1], Loss: 0.0373, Accuracy: 100.00%
# Epoch [90/100], Step [1/1], Loss: 0.0309, Accuracy: 100.00%
# Epoch [95/100], Step [1/1], Loss: 0.0213, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.0162, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 97.855 %
# Size=200, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.6678, Accuracy: 64.50%
# Epoch [10/100], Step [1/1], Loss: 0.6270, Accuracy: 67.50%
# Epoch [15/100], Step [1/1], Loss: 0.6094, Accuracy: 69.50%
# Epoch [20/100], Step [1/1], Loss: 0.5739, Accuracy: 70.50%
# Epoch [25/100], Step [1/1], Loss: 0.5574, Accuracy: 74.00%
# Epoch [30/100], Step [1/1], Loss: 0.5354, Accuracy: 71.00%
# Epoch [35/100], Step [1/1], Loss: 0.4686, Accuracy: 79.50%
# Epoch [40/100], Step [1/1], Loss: 0.4039, Accuracy: 84.00%
# Epoch [45/100], Step [1/1], Loss: 0.3164, Accuracy: 90.50%
# Epoch [50/100], Step [1/1], Loss: 0.2518, Accuracy: 92.50%
# Epoch [55/100], Step [1/1], Loss: 0.1915, Accuracy: 95.00%
# Epoch [60/100], Step [1/1], Loss: 0.1248, Accuracy: 98.00%
# Epoch [65/100], Step [1/1], Loss: 0.0819, Accuracy: 99.50%
# Epoch [70/100], Step [1/1], Loss: 0.0510, Accuracy: 99.50%
# Epoch [75/100], Step [1/1], Loss: 0.0317, Accuracy: 99.50%
# Epoch [80/100], Step [1/1], Loss: 0.0247, Accuracy: 99.50%
# Epoch [85/100], Step [1/1], Loss: 0.0325, Accuracy: 98.50%
# Epoch [90/100], Step [1/1], Loss: 0.0188, Accuracy: 99.50%
# Epoch [95/100], Step [1/1], Loss: 0.0154, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 99.1 %
# Size=200, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6499, Accuracy: 62.50%
# Epoch [10/100], Step [1/1], Loss: 0.6229, Accuracy: 65.00%
# Epoch [15/100], Step [1/1], Loss: 0.6116, Accuracy: 64.00%
# Epoch [20/100], Step [1/1], Loss: 0.5870, Accuracy: 67.50%
# Epoch [25/100], Step [1/1], Loss: 0.5615, Accuracy: 70.00%
# Epoch [30/100], Step [1/1], Loss: 0.5280, Accuracy: 75.50%
# Epoch [35/100], Step [1/1], Loss: 0.4698, Accuracy: 77.50%
# Epoch [40/100], Step [1/1], Loss: 0.4149, Accuracy: 84.00%
# Epoch [45/100], Step [1/1], Loss: 0.3517, Accuracy: 88.00%
# Epoch [50/100], Step [1/1], Loss: 0.2899, Accuracy: 90.50%
# Epoch [55/100], Step [1/1], Loss: 0.2169, Accuracy: 94.50%
# Epoch [60/100], Step [1/1], Loss: 0.1581, Accuracy: 94.50%
# Epoch [65/100], Step [1/1], Loss: 0.0947, Accuracy: 99.00%
# Epoch [70/100], Step [1/1], Loss: 0.0728, Accuracy: 99.50%
# Epoch [75/100], Step [1/1], Loss: 0.0839, Accuracy: 97.50%
# Epoch [80/100], Step [1/1], Loss: 0.0360, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0334, Accuracy: 99.50%
# Epoch [90/100], Step [1/1], Loss: 0.0271, Accuracy: 99.50%
# Epoch [95/100], Step [1/1], Loss: 0.0186, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.0216, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 97.69 %
# Size=400, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.6779, Accuracy: 54.00%
# Epoch [10/100], Step [1/1], Loss: 0.6728, Accuracy: 58.25%
# Epoch [15/100], Step [1/1], Loss: 0.6484, Accuracy: 64.00%
# Epoch [20/100], Step [1/1], Loss: 0.6171, Accuracy: 69.00%
# Epoch [25/100], Step [1/1], Loss: 0.5735, Accuracy: 70.25%
# Epoch [30/100], Step [1/1], Loss: 0.5377, Accuracy: 74.50%
# Epoch [35/100], Step [1/1], Loss: 0.4654, Accuracy: 80.75%
# Epoch [40/100], Step [1/1], Loss: 0.3764, Accuracy: 88.25%
# Epoch [45/100], Step [1/1], Loss: 0.3161, Accuracy: 88.50%
# Epoch [50/100], Step [1/1], Loss: 0.2393, Accuracy: 92.75%
# Epoch [55/100], Step [1/1], Loss: 0.1385, Accuracy: 97.50%
# Epoch [60/100], Step [1/1], Loss: 0.1157, Accuracy: 97.25%
# Epoch [65/100], Step [1/1], Loss: 0.1069, Accuracy: 97.25%
# Epoch [70/100], Step [1/1], Loss: 0.0646, Accuracy: 98.50%
# Epoch [75/100], Step [1/1], Loss: 0.0356, Accuracy: 99.75%
# Epoch [80/100], Step [1/1], Loss: 0.0323, Accuracy: 100.00%
# Epoch [85/100], Step [1/1], Loss: 0.0217, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 99.685 %
# Size=400, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.6796, Accuracy: 57.00%
# Epoch [10/100], Step [1/1], Loss: 0.6593, Accuracy: 60.00%
# Epoch [15/100], Step [1/1], Loss: 0.6217, Accuracy: 66.25%
# Epoch [20/100], Step [1/1], Loss: 0.5799, Accuracy: 71.75%
# Epoch [25/100], Step [1/1], Loss: 0.5246, Accuracy: 78.00%
# Epoch [30/100], Step [1/1], Loss: 0.4311, Accuracy: 84.50%
# Epoch [35/100], Step [1/1], Loss: 0.3233, Accuracy: 92.75%
# Epoch [40/100], Step [1/1], Loss: 0.2396, Accuracy: 95.00%
# Epoch [45/100], Step [1/1], Loss: 0.1784, Accuracy: 97.25%
# Epoch [50/100], Step [1/1], Loss: 0.1057, Accuracy: 98.75%
# Epoch [55/100], Step [1/1], Loss: 0.0817, Accuracy: 98.75%
# Epoch [60/100], Step [1/1], Loss: 0.0554, Accuracy: 99.00%
# Epoch [65/100], Step [1/1], Loss: 0.0350, Accuracy: 99.50%
# Epoch [70/100], Step [1/1], Loss: 0.0335, Accuracy: 99.25%
# Epoch [75/100], Step [1/1], Loss: 0.0205, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 99.425 %
# Size=400, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6813, Accuracy: 56.75%
# Epoch [10/100], Step [1/1], Loss: 0.6728, Accuracy: 57.75%
# Epoch [15/100], Step [1/1], Loss: 0.6563, Accuracy: 58.00%
# Epoch [20/100], Step [1/1], Loss: 0.6497, Accuracy: 61.00%
# Epoch [25/100], Step [1/1], Loss: 0.6353, Accuracy: 64.25%
# Epoch [30/100], Step [1/1], Loss: 0.5944, Accuracy: 70.50%
# Epoch [35/100], Step [1/1], Loss: 0.5212, Accuracy: 80.75%
# Epoch [40/100], Step [1/1], Loss: 0.4757, Accuracy: 80.75%
# Epoch [45/100], Step [1/1], Loss: 0.4145, Accuracy: 86.00%
# Epoch [50/100], Step [1/1], Loss: 0.3313, Accuracy: 89.00%
# Epoch [55/100], Step [1/1], Loss: 0.2370, Accuracy: 94.75%
# Epoch [60/100], Step [1/1], Loss: 0.1578, Accuracy: 96.50%
# Epoch [65/100], Step [1/1], Loss: 0.1140, Accuracy: 98.50%
# Epoch [70/100], Step [1/1], Loss: 0.0728, Accuracy: 99.25%
# Epoch [75/100], Step [1/1], Loss: 0.0541, Accuracy: 99.75%
# Epoch [80/100], Step [1/1], Loss: 0.0404, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 99.88 %
# Size=400, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.6848, Accuracy: 55.00%
# Epoch [10/100], Step [1/1], Loss: 0.6644, Accuracy: 58.75%
# Epoch [15/100], Step [1/1], Loss: 0.6587, Accuracy: 61.25%
# Epoch [20/100], Step [1/1], Loss: 0.6424, Accuracy: 66.50%
# Epoch [25/100], Step [1/1], Loss: 0.5927, Accuracy: 70.25%
# Epoch [30/100], Step [1/1], Loss: 0.5579, Accuracy: 75.00%
# Epoch [35/100], Step [1/1], Loss: 0.4774, Accuracy: 84.75%
# Epoch [40/100], Step [1/1], Loss: 0.3750, Accuracy: 88.50%
# Epoch [45/100], Step [1/1], Loss: 0.2687, Accuracy: 96.25%
# Epoch [50/100], Step [1/1], Loss: 0.1906, Accuracy: 98.25%
# Epoch [55/100], Step [1/1], Loss: 0.1074, Accuracy: 99.00%
# Epoch [60/100], Step [1/1], Loss: 0.0770, Accuracy: 98.50%
# Epoch [65/100], Step [1/1], Loss: 0.0544, Accuracy: 99.75%
# Epoch [70/100], Step [1/1], Loss: 0.0297, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 99.35000000000001 %
# Size=400, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6865, Accuracy: 54.25%
# Epoch [10/100], Step [1/1], Loss: 0.6743, Accuracy: 57.00%
# Epoch [15/100], Step [1/1], Loss: 0.6537, Accuracy: 61.00%
# Epoch [20/100], Step [1/1], Loss: 0.6309, Accuracy: 64.75%
# Epoch [25/100], Step [1/1], Loss: 0.5976, Accuracy: 70.00%
# Epoch [30/100], Step [1/1], Loss: 0.5397, Accuracy: 79.75%
# Epoch [35/100], Step [1/1], Loss: 0.4648, Accuracy: 84.25%
# Epoch [40/100], Step [1/1], Loss: 0.3641, Accuracy: 92.25%
# Epoch [45/100], Step [1/1], Loss: 0.2383, Accuracy: 95.50%
# Epoch [50/100], Step [1/1], Loss: 0.1417, Accuracy: 98.25%
# Epoch [55/100], Step [1/1], Loss: 0.0830, Accuracy: 99.00%
# Epoch [60/100], Step [1/1], Loss: 0.0613, Accuracy: 98.50%
# Epoch [65/100], Step [1/1], Loss: 0.0306, Accuracy: 99.75%
# Epoch [70/100], Step [1/1], Loss: 0.0217, Accuracy: 100.00%
# Epoch [75/100], Step [1/1], Loss: 0.0186, Accuracy: 99.75%
# Epoch [80/100], Step [1/1], Loss: 0.0149, Accuracy: 99.75%
# Test Accuracy of the model on the test images: 99.725 %
# Size=1000, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.7057, Accuracy: 50.00%
# Epoch [10/100], Step [1/1], Loss: 0.6867, Accuracy: 56.40%
# Epoch [15/100], Step [1/1], Loss: 0.6795, Accuracy: 60.10%
# Epoch [20/100], Step [1/1], Loss: 0.6690, Accuracy: 62.70%
# Epoch [25/100], Step [1/1], Loss: 0.6498, Accuracy: 66.10%
# Epoch [30/100], Step [1/1], Loss: 0.6233, Accuracy: 70.70%
# Epoch [35/100], Step [1/1], Loss: 0.5750, Accuracy: 78.60%
# Epoch [40/100], Step [1/1], Loss: 0.4881, Accuracy: 88.50%
# Epoch [45/100], Step [1/1], Loss: 0.3692, Accuracy: 94.60%
# Epoch [50/100], Step [1/1], Loss: 0.2427, Accuracy: 97.60%
# Epoch [55/100], Step [1/1], Loss: 0.1409, Accuracy: 99.10%
# Epoch [60/100], Step [1/1], Loss: 0.0826, Accuracy: 99.10%
# Epoch [65/100], Step [1/1], Loss: 0.0509, Accuracy: 99.50%
# Epoch [70/100], Step [1/1], Loss: 0.0300, Accuracy: 99.90%
# Epoch [75/100], Step [1/1], Loss: 0.0239, Accuracy: 99.70%
# Test Accuracy of the model on the test images: 99.81 %
# Size=1000, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.6996, Accuracy: 49.90%
# Epoch [10/100], Step [1/1], Loss: 0.6820, Accuracy: 60.10%
# Epoch [15/100], Step [1/1], Loss: 0.6701, Accuracy: 61.70%
# Epoch [20/100], Step [1/1], Loss: 0.6517, Accuracy: 63.90%
# Epoch [25/100], Step [1/1], Loss: 0.6152, Accuracy: 71.10%
# Epoch [30/100], Step [1/1], Loss: 0.5453, Accuracy: 81.20%
# Epoch [35/100], Step [1/1], Loss: 0.4525, Accuracy: 88.90%
# Epoch [40/100], Step [1/1], Loss: 0.3358, Accuracy: 94.30%
# Epoch [45/100], Step [1/1], Loss: 0.2187, Accuracy: 97.30%
# Epoch [50/100], Step [1/1], Loss: 0.1213, Accuracy: 99.20%
# Epoch [55/100], Step [1/1], Loss: 0.0659, Accuracy: 99.80%
# Epoch [60/100], Step [1/1], Loss: 0.0394, Accuracy: 99.80%
# Epoch [65/100], Step [1/1], Loss: 0.0281, Accuracy: 99.90%
# Epoch [70/100], Step [1/1], Loss: 0.0154, Accuracy: 100.00%
# Epoch [75/100], Step [1/1], Loss: 0.0138, Accuracy: 99.80%
# Test Accuracy of the model on the test images: 99.875 %
# Size=1000, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6849, Accuracy: 54.20%
# Epoch [10/100], Step [1/1], Loss: 0.6722, Accuracy: 60.20%
# Epoch [15/100], Step [1/1], Loss: 0.6457, Accuracy: 66.80%
# Epoch [20/100], Step [1/1], Loss: 0.6021, Accuracy: 72.90%
# Epoch [25/100], Step [1/1], Loss: 0.5317, Accuracy: 82.40%
# Epoch [30/100], Step [1/1], Loss: 0.4322, Accuracy: 85.90%
# Epoch [35/100], Step [1/1], Loss: 0.3182, Accuracy: 92.50%
# Epoch [40/100], Step [1/1], Loss: 0.2211, Accuracy: 95.30%
# Epoch [45/100], Step [1/1], Loss: 0.1409, Accuracy: 97.70%
# Epoch [50/100], Step [1/1], Loss: 0.0875, Accuracy: 98.70%
# Epoch [55/100], Step [1/1], Loss: 0.0557, Accuracy: 99.10%
# Epoch [60/100], Step [1/1], Loss: 0.0373, Accuracy: 99.70%
# Epoch [65/100], Step [1/1], Loss: 0.0240, Accuracy: 99.80%
# Test Accuracy of the model on the test images: 99.815 %
# Size=1000, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.6983, Accuracy: 50.10%
# Epoch [10/100], Step [1/1], Loss: 0.6875, Accuracy: 54.80%
# Epoch [15/100], Step [1/1], Loss: 0.6790, Accuracy: 55.80%
# Epoch [20/100], Step [1/1], Loss: 0.6727, Accuracy: 58.70%
# Epoch [25/100], Step [1/1], Loss: 0.6595, Accuracy: 60.50%
# Epoch [30/100], Step [1/1], Loss: 0.6381, Accuracy: 64.20%
# Epoch [35/100], Step [1/1], Loss: 0.6120, Accuracy: 70.20%
# Epoch [40/100], Step [1/1], Loss: 0.5545, Accuracy: 78.10%
# Epoch [45/100], Step [1/1], Loss: 0.4762, Accuracy: 85.10%
# Epoch [50/100], Step [1/1], Loss: 0.3882, Accuracy: 90.20%
# Epoch [55/100], Step [1/1], Loss: 0.2951, Accuracy: 92.80%
# Epoch [60/100], Step [1/1], Loss: 0.2164, Accuracy: 93.40%
# Epoch [65/100], Step [1/1], Loss: 0.1385, Accuracy: 97.50%
# Epoch [70/100], Step [1/1], Loss: 0.0893, Accuracy: 98.80%
# Epoch [75/100], Step [1/1], Loss: 0.0678, Accuracy: 98.90%
# Epoch [80/100], Step [1/1], Loss: 0.0498, Accuracy: 99.60%
# Epoch [85/100], Step [1/1], Loss: 0.0332, Accuracy: 99.50%
# Epoch [90/100], Step [1/1], Loss: 0.0275, Accuracy: 99.70%
# Test Accuracy of the model on the test images: 99.87 %
# Size=1000, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6807, Accuracy: 55.90%
# Epoch [10/100], Step [1/1], Loss: 0.6613, Accuracy: 61.40%
# Epoch [15/100], Step [1/1], Loss: 0.6311, Accuracy: 66.40%
# Epoch [20/100], Step [1/1], Loss: 0.5784, Accuracy: 72.50%
# Epoch [25/100], Step [1/1], Loss: 0.4939, Accuracy: 83.10%
# Epoch [30/100], Step [1/1], Loss: 0.3884, Accuracy: 88.40%
# Epoch [35/100], Step [1/1], Loss: 0.2870, Accuracy: 94.20%
# Epoch [40/100], Step [1/1], Loss: 0.1847, Accuracy: 97.20%
# Epoch [45/100], Step [1/1], Loss: 0.1204, Accuracy: 97.80%
# Epoch [50/100], Step [1/1], Loss: 0.0818, Accuracy: 99.00%
# Epoch [55/100], Step [1/1], Loss: 0.0452, Accuracy: 99.70%
# Epoch [60/100], Step [1/1], Loss: 0.0359, Accuracy: 99.20%
# Epoch [65/100], Step [1/1], Loss: 0.0276, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 99.885 %
# Size=2000, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.6964, Accuracy: 50.30%
# Epoch [10/100], Step [1/1], Loss: 0.6834, Accuracy: 56.30%
# Epoch [15/100], Step [1/1], Loss: 0.6747, Accuracy: 59.35%
# Epoch [20/100], Step [1/1], Loss: 0.6580, Accuracy: 64.60%
# Epoch [25/100], Step [1/1], Loss: 0.6275, Accuracy: 70.35%
# Epoch [30/100], Step [1/1], Loss: 0.5759, Accuracy: 75.95%
# Epoch [35/100], Step [1/1], Loss: 0.4982, Accuracy: 83.80%
# Epoch [40/100], Step [1/1], Loss: 0.3929, Accuracy: 88.70%
# Epoch [45/100], Step [1/1], Loss: 0.2872, Accuracy: 94.30%
# Epoch [50/100], Step [1/1], Loss: 0.1858, Accuracy: 97.50%
# Epoch [55/100], Step [1/1], Loss: 0.1101, Accuracy: 98.95%
# Epoch [60/100], Step [1/1], Loss: 0.0736, Accuracy: 99.10%
# Epoch [65/100], Step [1/1], Loss: 0.0465, Accuracy: 99.55%
# Epoch [70/100], Step [1/1], Loss: 0.0303, Accuracy: 99.65%
# Epoch [75/100], Step [1/1], Loss: 0.0247, Accuracy: 99.80%
# Test Accuracy of the model on the test images: 99.91499999999999 %
# Size=2000, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.6914, Accuracy: 50.65%
# Epoch [10/100], Step [1/1], Loss: 0.6766, Accuracy: 63.65%
# Epoch [15/100], Step [1/1], Loss: 0.6527, Accuracy: 68.00%
# Epoch [20/100], Step [1/1], Loss: 0.6047, Accuracy: 76.25%
# Epoch [25/100], Step [1/1], Loss: 0.5308, Accuracy: 84.60%
# Epoch [30/100], Step [1/1], Loss: 0.4244, Accuracy: 92.20%
# Epoch [35/100], Step [1/1], Loss: 0.3236, Accuracy: 93.00%
# Epoch [40/100], Step [1/1], Loss: 0.2210, Accuracy: 96.60%
# Epoch [45/100], Step [1/1], Loss: 0.1476, Accuracy: 98.30%
# Epoch [50/100], Step [1/1], Loss: 0.0944, Accuracy: 99.00%
# Epoch [55/100], Step [1/1], Loss: 0.0617, Accuracy: 99.35%
# Epoch [60/100], Step [1/1], Loss: 0.0404, Accuracy: 99.65%
# Epoch [65/100], Step [1/1], Loss: 0.0292, Accuracy: 99.60%
# Epoch [70/100], Step [1/1], Loss: 0.0215, Accuracy: 99.85%
# Test Accuracy of the model on the test images: 99.94 %
# Size=2000, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6884, Accuracy: 52.15%
# Epoch [10/100], Step [1/1], Loss: 0.6747, Accuracy: 59.80%
# Epoch [15/100], Step [1/1], Loss: 0.6448, Accuracy: 68.25%
# Epoch [20/100], Step [1/1], Loss: 0.5885, Accuracy: 78.55%
# Epoch [25/100], Step [1/1], Loss: 0.4979, Accuracy: 88.55%
# Epoch [30/100], Step [1/1], Loss: 0.3742, Accuracy: 95.00%
# Epoch [35/100], Step [1/1], Loss: 0.2433, Accuracy: 96.95%
# Epoch [40/100], Step [1/1], Loss: 0.1364, Accuracy: 98.60%
# Epoch [45/100], Step [1/1], Loss: 0.0778, Accuracy: 99.10%
# Epoch [50/100], Step [1/1], Loss: 0.0444, Accuracy: 99.60%
# Epoch [55/100], Step [1/1], Loss: 0.0280, Accuracy: 99.75%
# Epoch [60/100], Step [1/1], Loss: 0.0206, Accuracy: 99.70%
# Test Accuracy of the model on the test images: 99.92999999999999 %
# Size=2000, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.7026, Accuracy: 50.00%
# Epoch [10/100], Step [1/1], Loss: 0.6861, Accuracy: 51.30%
# Epoch [15/100], Step [1/1], Loss: 0.6703, Accuracy: 67.75%
# Epoch [20/100], Step [1/1], Loss: 0.6465, Accuracy: 71.10%
# Epoch [25/100], Step [1/1], Loss: 0.6005, Accuracy: 81.85%
# Epoch [30/100], Step [1/1], Loss: 0.5080, Accuracy: 91.00%
# Epoch [35/100], Step [1/1], Loss: 0.3729, Accuracy: 96.25%
# Epoch [40/100], Step [1/1], Loss: 0.2322, Accuracy: 98.60%
# Epoch [45/100], Step [1/1], Loss: 0.1239, Accuracy: 99.00%
# Epoch [50/100], Step [1/1], Loss: 0.0619, Accuracy: 99.60%
# Epoch [55/100], Step [1/1], Loss: 0.0318, Accuracy: 99.85%
# Epoch [60/100], Step [1/1], Loss: 0.0196, Accuracy: 99.80%
# Test Accuracy of the model on the test images: 99.98 %
# Size=2000, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6887, Accuracy: 54.05%
# Epoch [10/100], Step [1/1], Loss: 0.6828, Accuracy: 58.25%
# Epoch [15/100], Step [1/1], Loss: 0.6706, Accuracy: 62.10%
# Epoch [20/100], Step [1/1], Loss: 0.6472, Accuracy: 67.10%
# Epoch [25/100], Step [1/1], Loss: 0.6052, Accuracy: 74.40%
# Epoch [30/100], Step [1/1], Loss: 0.5352, Accuracy: 81.40%
# Epoch [35/100], Step [1/1], Loss: 0.4453, Accuracy: 87.85%
# Epoch [40/100], Step [1/1], Loss: 0.3324, Accuracy: 93.75%
# Epoch [45/100], Step [1/1], Loss: 0.2241, Accuracy: 96.25%
# Epoch [50/100], Step [1/1], Loss: 0.1404, Accuracy: 98.30%
# Epoch [55/100], Step [1/1], Loss: 0.0834, Accuracy: 99.40%
# Epoch [60/100], Step [1/1], Loss: 0.0489, Accuracy: 99.70%
# Epoch [65/100], Step [1/1], Loss: 0.0356, Accuracy: 99.55%
# Epoch [70/100], Step [1/1], Loss: 0.0243, Accuracy: 99.85%
# Test Accuracy of the model on the test images: 99.92999999999999 %
