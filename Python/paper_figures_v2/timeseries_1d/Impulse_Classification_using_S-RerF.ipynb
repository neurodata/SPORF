# %% [markdown]
# # Structured RerF Demo: Impulse Response
# We form a two-class classification problem where each data point is 100 timesteps. Class 0 is simply white noise while class 1 is white noise plus an exponentially decaying unit impulse beginning at timestep 20.
#
# We test the performance of S-Rerf and a set of other classification algorithms, training each on samples of sizes $n \in \{50,100,200,400,1000,2000\}$, each containing an equal number of data points in each class. The average 0-1 loss is evaluated for each algorithm for each training size using a single test set of size $m=10000$ with an equal number of data points in each class.

# %%
import numpy as np
import pandas as pd
from scipy import stats

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline
import seaborn as sns

import pickle
import time
from tqdm import tqdm

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

from rerf.rerfClassifier import rerfClassifier

import warnings
warnings.simplefilter('ignore')

# %%
def samp(n, cls=0, separate=False):
    ## Sample n samples from either class 0 or 1
    ## Class 1 has the impulse added
    M0 = 20 # Onset of impulse response
    M1 = 100-M0
    func = lambda x: [np.exp(-0.1*(j-M0)) if j >= M0 else 0.0 for j in x] # Impulse response function
    if cls == 0:
        X = np.full((n,M0+M1),0.0)
        Y = np.full(n,cls)
    elif cls == 1:
        X = np.tile(func(np.arange(0,M0+M1)),reps=(n,1))
        Y = np.full(n,cls)
    
    if separate:
        # White noise
        noise = np.random.normal(0,1,size=(n,M0+M1))
        
        return(X,Y,noise)
    else:
        # White noise
        X += np.random.normal(0,1,size=(n,M0+M1))

        return(X,Y)

def mixed_samp(n0,n1,shuffle=True):
    ## Generate a collection of mixed class (shuffled) observations
    X0,Y0 = samp(n0,cls=0)
    X1,Y1 = samp(n1,cls=1)
    X = np.vstack([X0,X1])
    Y = np.hstack([Y0,Y1])
    if shuffle:
        shuffled_idx= list(range(n0+n1)); np.random.shuffle(shuffled_idx)
        X = X[shuffled_idx]
        Y = Y[shuffled_idx]
    return(X,Y)

# %%
np.random.seed(1234)
ns = np.array([10,50,100,200,400,1000,2000])
TRAIN_FRAC = 0.5
n0 = [int(i*TRAIN_FRAC) for i in ns]
n1 = n0

X_train, Y_train = np.empty(shape=(0,100)), np.empty(shape=(0))
for l0,l1 in zip(np.append(n0[0],np.diff(a=n0)),
                 np.append(n1[0],np.diff(a=n1))):
    x, y = mixed_samp(l0,l1)
    X_train = np.vstack((X_train, x))
    Y_train = np.hstack((Y_train, y))

TEST_SIZE = 10000
X_test, Y_test = mixed_samp(int(TEST_SIZE*0.5),int(TEST_SIZE*0.5))

# %%
fontsize = 9
sns.set(); sns.set(style="dark", 
                   rc={'font.size':fontsize, 
                     'legend.fontsize': fontsize,
                     'xtick.labelsize': fontsize,
                     'ytick.labelsize': fontsize,
                     'axes.labelsize': fontsize,
                     'axes.titlesize': fontsize})
#sns.set_style({'axes.grid' : False})
matplotlib.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

# %%
plt.clf()
np.random.seed(1234)
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True, figsize=(2,1))

X0, Y0 = samp(2,cls=0)
X1, Y1, noise = samp(2,cls=1, separate=True)

axes[0,0].plot(X0[0,:], alpha=0.6, label='Signal')
#axes[0,0].legend(loc='lower left',frameon=False)
axes[0,0].set_title("Class 0")
#axes[0,0].set_ylabel("Observed Values")

axes[0,1].plot(X0[1,:], alpha=0.6, label='Signal')
#axes[0,1].legend(loc='lower left',frameon=False)
axes[0,1].set_title("Class 0")

axes[1,0].plot(X1[0,:] + noise[0,:], label='Signal', alpha=0.6)
axes[1,0].plot(X1[0,:], label='Impulse', alpha=0.6)
#axes[1,0].legend(loc='lower left',frameon=False)
axes[1,0].set_title("Class 1")
#axes[1,0].set_xlabel("Timestep")
#axes[1,0].set_ylabel("Observed Values")

axes[1,1].plot(X1[1,:] + noise[1,:], label='Signal', alpha=0.6)
axes[1,1].plot(X1[1,:], label='Impulse', alpha=0.6)
#axes[1,1].legend(loc='lower left',frameon=False)
axes[1,1].set_title("Class 1")
#axes[1,1].set_xlabel("Timestep")

for idx1 in range(2):
    for idx2 in range(2):
        axes[idx1,idx2].tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)
        axes[idx1,idx2].set_title('')

handles, labels = axes[1,1].get_legend_handles_labels()
lgd = axes[0,1].legend(handles, labels, loc='upper left',bbox_to_anchor = (1.04,1), borderaxespad=0)

bax = fig.add_subplot(111, frameon=False)

bax.grid(False)
plt.tick_params(labelcolor='none', top=False, bottom=False, left=False, right=False)

#plt.ylabel('Signal Values')
#plt.xlabel('Timestep')

plt.tight_layout()
#fig.subplots_adjust(wspace=0.12)
plt.savefig('../impulse_sample_minimal.pdf',bbox_inches='tight',bbox_extra_artists=(lgd,), format='pdf')
plt.show()

# %%
## Setup for run
names = {"Log. Reg": "#a6cee3", 
         "Lin. SVM":"#1f78b4", 
         "SVM":"#b2df8a", 
         "kNN": "#33a02c", 
         "RF":"#fb9a99", 
         "MLP":"#fdbf6f", 
         "RerF":"#ff7f00", 
         "S-RerF":"#e31a1c",
         "CNN":"#cab2d6"}

ncores=1
num_runs=1
n_est=100

classifiers = [
    LogisticRegression(random_state=0, n_jobs=ncores, solver='liblinear'),
    LinearSVC(),
    SVC(C=1.0, kernel='rbf', gamma='auto',random_state=0),
    KNeighborsClassifier(3, n_jobs=ncores),
    RandomForestClassifier(n_estimators=n_est, max_features='auto', n_jobs=ncores),
    MLPClassifier(hidden_layer_sizes=(100, ), random_state=0, max_iter=1000),
    rerfClassifier(n_estimators = n_est, projection_matrix = "RerF",
                    max_features = 'auto', n_jobs = ncores),
    rerfClassifier(projection_matrix="S-RerF",
                   max_features='auto',
                   n_jobs=ncores,
                    n_estimators=n_est,
                    oob_score=False,
                    random_state=0,
                    image_height=1,
                    image_width=100,
                    patch_height_max=1,
                    patch_height_min=1,
                    patch_width_max=5,
                    patch_width_min=1
                   )
    ]

# %%
# Train each classifier on each dataset size, then test
## Prep output file:
f = open('s-rerf_impulse_experiment_rerf_1run.csv', 'w+')
f.write("classifier,n,Lhat,trainTime,testTime,iterate\n")
f.flush()

runList = [(n, clf, run) for n in ns\
                       for clf in zip(classifiers, [key for key in names])\
                       for run in range(num_runs)]

for n, clf, iteration in tqdm(runList):
        X = X_train[:n]
        y = Y_train[:n]

        trainStartTime = time.time()
        clf[0].fit(X, y)
        trainEndTime = time.time()
        trainTime = trainEndTime - trainStartTime

        testStartTime = time.time()
        out = clf[0].predict(X_test)
        testEndTime = time.time()
        testTime = testEndTime - testStartTime

        lhat = np.mean(np.not_equal(out, Y_test).astype(int))


        ####("variable,Lhat,trainTime,testTime,iterate")
        f.write(f"{clf[1]}, {n}, {lhat:2.9f}, {trainTime:2.9f}, {testTime:2.9f}, {iteration}\n")
        f.flush()

f.close()
# Out:
# 100%|██████████| 56/56 [00:48<00:00,  3.03s/it]

# %%
## Sklearn algos
dat = pd.read_csv("s-rerf_impulse_experiment_rerf_1run.csv")

#d1 = pd.DataFrame(columns = ['classifier', 'n', 'Lhat', 'se', 'color'])
d1 = pd.DataFrame(columns = ['classifier', 'n', 'Lhat', 'color'])

k = 0
for ni in np.unique(dat['n']):
    for cl in np.unique(dat['classifier']):

        tmp = dat[np.logical_and(dat['classifier'] == cl,dat['n'] == ni)][['n', 'Lhat']]

        se = stats.sem(tmp['Lhat'])
        
        list(tmp.mean())
        #d1.loc[k] = [cl] + list(tmp.mean()) + [se] + [names[cl]]
        d1.loc[k] = [cl] + list(tmp.mean()) + [names[cl]]
        k += 1

## CNN ADDON
dat2 = pd.read_csv("impulse_cnn_results_5runs.csv")

for ni in np.unique(dat2['n']):
    for cl in np.unique(dat2['classifier']):
        if not cl in names.keys():
            continue
            
        tmp = dat2[np.logical_and(dat2['classifier'] == cl,dat2['n'] == ni)][['n', 'Lhat']]
        
        se = stats.sem(tmp['Lhat'])
        
        list(tmp.mean())
        #d1.loc[k] = [cl] + list(tmp.mean()) + [se] + [names[cl]]
        d1.loc[k] = [cl] + list(tmp.mean()) + [names[cl]]
        k += 1
        
## Plot

fontsize = 11

sns.set(); sns.set(style="darkgrid", rc={"font.size":fontsize,"axes.titlesize":fontsize,"axes.labelsize":fontsize})  
fig, ax = plt.subplots(figsize = (4.5,5))

for key in names.keys():
    grp = d1[d1['classifier'] == key] 
    ax = grp.plot(ax=ax, kind='line', x='n', y='Lhat', label=key, \
            c = names[key], alpha =0.65)
    ax.set_xscale('log')

lgd = ax.legend(title='Algorithm', loc='upper left',bbox_to_anchor = (1.04,1), borderaxespad=0, frameon=False)#plt.legend(loc='upper right',title='Algorithm')
plt.title('Impulse Classification Results')
plt.ylabel('Misclassification Rate')
plt.xlabel('Number of training samples')
plt.tight_layout()
#plt.savefig('./s-rerf_impulse_experiment.pdf',format='pdf')
plt.show()

# %% [markdown]
# ## CNN Classification

# %%
import torch
import torch.nn as nn
import torch.utils.data as utils
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

# %%
# Hyperparameters
num_epochs = 100
num_classes = 2
batch_size = 200
learning_rate = 0.001
num_cnn_runs = 5

# %%
tensor_x = torch.from_numpy(np.reshape(X_test,(X_test.shape[0],1,X_test.shape[1]))).float()
tensor_y = torch.from_numpy(np.asarray(Y_test)).long()

test_tensor = utils.TensorDataset(tensor_x,tensor_y) # create your datset
test_loader = DataLoader(dataset=test_tensor, batch_size=batch_size, shuffle=False)

# %%
# Convolutional neural network (two convolutional layers)
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=10, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2))
        self.layer2 = nn.Sequential(
            nn.Conv1d(32, 64, kernel_size=10, stride=1, padding=0),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2))
        self.drop_out = nn.Dropout(p=0.5)
        self.fc1 = nn.Linear(18 * 64, 500)
        self.fc2 = nn.Linear(500, 2)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.drop_out(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
def cnn_learn(n, model):
    ## Data loader
    batch_size = int(n)
    
    X = X_train[0:n, ::]
    Y = Y_train[0:n]
    
    tensor_x = torch.from_numpy(np.reshape(X,(X.shape[0],1,X.shape[1]))).float()
    tensor_y = torch.from_numpy(np.asanyarray(Y)).long()

    train_tensor = utils.TensorDataset(tensor_x,tensor_y) # create your datset

    train_loader = DataLoader(dataset=train_tensor, batch_size=batch_size, shuffle=True)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    # Train the model
    trainStartTime = time.time()
    
    total_step = len(train_loader)
    loss_list = []
    acc_list = []

    prior_loss = []
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(train_loader):
            #images = images.float(); labels = labels.long()
            # Run the forward pass
            outputs = model(images.float())
            loss = criterion(outputs, labels.long())
            loss_list.append(loss.item())

            # Backprop and perform Adam optimisation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track the accuracy
            total = labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct = (predicted == labels).sum().item()
            acc_list.append(correct / total)
            curr_loss = loss.item()
            if ((i + 1) % 1 == 0) and ((epoch + 1) % 5 == 0):
                print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                      .format(epoch + 1, num_epochs, i + 1, total_step, curr_loss,
                              (correct / total) * 100))
        if epoch > 10:
            if stats.sem(prior_loss[-5:]) < 0.001:
                break
        prior_loss.append(loss.item())
    
    trainEndTime = time.time()
    trainTime = trainEndTime - trainStartTime
    
    # Test the model
    testStartTime = time.time()
    
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
        testEndTime = time.time()
        testTime = testEndTime - testStartTime
        print('Test Accuracy of the model on the test images: {} %'.format((correct / total) * 100))
        
        lhat = 1- correct / total

        ####("variable,Lhat,trainTime,testTime,iterate")
        clf = "CNN"; iterate = 1
        
        return((clf,n,lhat,trainTime,testTime,iterate))

# %%
## Log output
np.random.seed(1234)

write_path = 'impulse_cnn_results_5runs.csv'

with open(write_path, 'w') as f:
    f.write("classifier,n,Lhat,trainTime,testTime,iterate\n")
    
runList = [(n, iterate) for n in ns\
                        for iterate in range(1, num_cnn_runs + 1)]

for n, iterate in runList:
    print(f"Size={n}, Iterate {iterate}")
    model = ConvNet()
    clf,n,lhat,trainTime,testTime,iterate = cnn_learn(n, model)
    
    with open(write_path, 'a') as f:
        f.write(f"{clf}, {n}, {lhat:2.9f}, {trainTime:2.9f}, {testTime:2.9f}, {iterate}\n")
# Out:
# Size=10, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.1941, Accuracy: 100.00%
# Epoch [10/100], Step [1/1], Loss: 0.0115, Accuracy: 100.00%
# Epoch [15/100], Step [1/1], Loss: 0.0004, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 66.88 %
# Size=10, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.1623, Accuracy: 100.00%
# Epoch [10/100], Step [1/1], Loss: 0.0150, Accuracy: 100.00%
# Epoch [15/100], Step [1/1], Loss: 0.0038, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 65.02 %
# Size=10, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.1519, Accuracy: 100.00%
# Epoch [10/100], Step [1/1], Loss: 0.0077, Accuracy: 100.00%
# Epoch [15/100], Step [1/1], Loss: 0.0023, Accuracy: 100.00%
# Epoch [20/100], Step [1/1], Loss: 0.0028, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0001, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 76.34 %
# Size=10, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.1591, Accuracy: 100.00%
# Epoch [10/100], Step [1/1], Loss: 0.0085, Accuracy: 100.00%
# Epoch [15/100], Step [1/1], Loss: 0.0020, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 76.14999999999999 %
# Size=10, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.2176, Accuracy: 100.00%
# Epoch [10/100], Step [1/1], Loss: 0.0079, Accuracy: 100.00%
# Epoch [15/100], Step [1/1], Loss: 0.0004, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 74.39 %
# Size=50, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.4338, Accuracy: 76.00%
# Epoch [10/100], Step [1/1], Loss: 0.1675, Accuracy: 96.00%
# Epoch [15/100], Step [1/1], Loss: 0.0752, Accuracy: 98.00%
# Epoch [20/100], Step [1/1], Loss: 0.0105, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0070, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0012, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0043, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 80.55 %
# Size=50, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.5444, Accuracy: 62.00%
# Epoch [10/100], Step [1/1], Loss: 0.1791, Accuracy: 100.00%
# Epoch [15/100], Step [1/1], Loss: 0.0812, Accuracy: 98.00%
# Epoch [20/100], Step [1/1], Loss: 0.0230, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0139, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0105, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0038, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 82.75 %
# Size=50, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6388, Accuracy: 50.00%
# Epoch [10/100], Step [1/1], Loss: 0.4507, Accuracy: 92.00%
# Epoch [15/100], Step [1/1], Loss: 0.2158, Accuracy: 96.00%
# Epoch [20/100], Step [1/1], Loss: 0.0802, Accuracy: 96.00%
# Epoch [25/100], Step [1/1], Loss: 0.0363, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.1000, Accuracy: 94.00%
# Epoch [35/100], Step [1/1], Loss: 0.0051, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0138, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0014, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 80.07 %
# Size=50, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.5654, Accuracy: 58.00%
# Epoch [10/100], Step [1/1], Loss: 0.2612, Accuracy: 96.00%
# Epoch [15/100], Step [1/1], Loss: 0.1029, Accuracy: 100.00%
# Epoch [20/100], Step [1/1], Loss: 0.0253, Accuracy: 100.00%
# Epoch [25/100], Step [1/1], Loss: 0.0380, Accuracy: 98.00%
# Epoch [30/100], Step [1/1], Loss: 0.0065, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0014, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 81.23 %
# Size=50, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6263, Accuracy: 60.00%
# Epoch [10/100], Step [1/1], Loss: 0.2584, Accuracy: 98.00%
# Epoch [15/100], Step [1/1], Loss: 0.1340, Accuracy: 98.00%
# Epoch [20/100], Step [1/1], Loss: 0.0478, Accuracy: 98.00%
# Epoch [25/100], Step [1/1], Loss: 0.0341, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0143, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0128, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0066, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0021, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 82.65 %
# Size=100, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.5246, Accuracy: 73.00%
# Epoch [10/100], Step [1/1], Loss: 0.2598, Accuracy: 95.00%
# Epoch [15/100], Step [1/1], Loss: 0.1339, Accuracy: 96.00%
# Epoch [20/100], Step [1/1], Loss: 0.0814, Accuracy: 96.00%
# Epoch [25/100], Step [1/1], Loss: 0.0288, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0201, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0047, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0037, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 83.44 %
# Size=100, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.5862, Accuracy: 59.00%
# Epoch [10/100], Step [1/1], Loss: 0.2857, Accuracy: 89.00%
# Epoch [15/100], Step [1/1], Loss: 0.1358, Accuracy: 98.00%
# Epoch [20/100], Step [1/1], Loss: 0.0948, Accuracy: 98.00%
# Epoch [25/100], Step [1/1], Loss: 0.0830, Accuracy: 97.00%
# Epoch [30/100], Step [1/1], Loss: 0.0138, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0116, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0266, Accuracy: 99.00%
# Epoch [45/100], Step [1/1], Loss: 0.0039, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 84.07 %
# Size=100, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.5642, Accuracy: 61.00%
# Epoch [10/100], Step [1/1], Loss: 0.2719, Accuracy: 94.00%
# Epoch [15/100], Step [1/1], Loss: 0.1717, Accuracy: 94.00%
# Epoch [20/100], Step [1/1], Loss: 0.0866, Accuracy: 99.00%
# Epoch [25/100], Step [1/1], Loss: 0.0449, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0156, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0077, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 85.38 %
# Size=100, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.5869, Accuracy: 58.00%
# Epoch [10/100], Step [1/1], Loss: 0.3563, Accuracy: 86.00%
# Epoch [15/100], Step [1/1], Loss: 0.1987, Accuracy: 91.00%
# Epoch [20/100], Step [1/1], Loss: 0.1013, Accuracy: 96.00%
# Epoch [25/100], Step [1/1], Loss: 0.0537, Accuracy: 98.00%
# Epoch [30/100], Step [1/1], Loss: 0.0176, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0204, Accuracy: 99.00%
# Epoch [40/100], Step [1/1], Loss: 0.0189, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0040, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 82.69999999999999 %
# Size=100, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.4133, Accuracy: 88.00%
# Epoch [10/100], Step [1/1], Loss: 0.1657, Accuracy: 95.00%
# Epoch [15/100], Step [1/1], Loss: 0.1136, Accuracy: 94.00%
# Epoch [20/100], Step [1/1], Loss: 0.0681, Accuracy: 98.00%
# Epoch [25/100], Step [1/1], Loss: 0.0240, Accuracy: 100.00%
# Epoch [30/100], Step [1/1], Loss: 0.0211, Accuracy: 100.00%
# Epoch [35/100], Step [1/1], Loss: 0.0104, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 84.39 %
# Size=200, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.5692, Accuracy: 75.00%
# Epoch [10/100], Step [1/1], Loss: 0.4434, Accuracy: 86.00%
# Epoch [15/100], Step [1/1], Loss: 0.2683, Accuracy: 89.50%
# Epoch [20/100], Step [1/1], Loss: 0.2558, Accuracy: 89.50%
# Epoch [25/100], Step [1/1], Loss: 0.1850, Accuracy: 93.00%
# Epoch [30/100], Step [1/1], Loss: 0.1392, Accuracy: 94.50%
# Epoch [35/100], Step [1/1], Loss: 0.0924, Accuracy: 98.00%
# Epoch [40/100], Step [1/1], Loss: 0.0657, Accuracy: 98.00%
# Epoch [45/100], Step [1/1], Loss: 0.0452, Accuracy: 100.00%
# Epoch [50/100], Step [1/1], Loss: 0.0181, Accuracy: 100.00%
# Epoch [55/100], Step [1/1], Loss: 0.0230, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 84.11 %
# Size=200, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.5506, Accuracy: 70.00%
# Epoch [10/100], Step [1/1], Loss: 0.4019, Accuracy: 84.00%
# Epoch [15/100], Step [1/1], Loss: 0.2931, Accuracy: 88.50%
# Epoch [20/100], Step [1/1], Loss: 0.2493, Accuracy: 88.50%
# Epoch [25/100], Step [1/1], Loss: 0.1838, Accuracy: 93.00%
# Epoch [30/100], Step [1/1], Loss: 0.1512, Accuracy: 94.00%
# Epoch [35/100], Step [1/1], Loss: 0.0892, Accuracy: 97.50%
# Epoch [40/100], Step [1/1], Loss: 0.0743, Accuracy: 98.00%
# Epoch [45/100], Step [1/1], Loss: 0.0668, Accuracy: 98.50%
# Epoch [50/100], Step [1/1], Loss: 0.0167, Accuracy: 100.00%
# Epoch [55/100], Step [1/1], Loss: 0.0197, Accuracy: 99.50%
# Epoch [60/100], Step [1/1], Loss: 0.0140, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 84.5 %
# Size=200, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.5655, Accuracy: 62.00%
# Epoch [10/100], Step [1/1], Loss: 0.2975, Accuracy: 90.00%
# Epoch [15/100], Step [1/1], Loss: 0.2419, Accuracy: 89.00%
# Epoch [20/100], Step [1/1], Loss: 0.1476, Accuracy: 93.50%
# Epoch [25/100], Step [1/1], Loss: 0.1328, Accuracy: 94.50%
# Epoch [30/100], Step [1/1], Loss: 0.0633, Accuracy: 98.00%
# Epoch [35/100], Step [1/1], Loss: 0.0298, Accuracy: 100.00%
# Epoch [40/100], Step [1/1], Loss: 0.0202, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0125, Accuracy: 100.00%
# Epoch [50/100], Step [1/1], Loss: 0.0134, Accuracy: 99.50%
# Epoch [55/100], Step [1/1], Loss: 0.0104, Accuracy: 100.00%
# Test Accuracy of the model on the test images: 84.5 %
# Size=200, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.5227, Accuracy: 85.50%
# Epoch [10/100], Step [1/1], Loss: 0.3565, Accuracy: 86.50%
# Epoch [15/100], Step [1/1], Loss: 0.2311, Accuracy: 90.00%
# Epoch [20/100], Step [1/1], Loss: 0.1581, Accuracy: 94.00%
# Epoch [25/100], Step [1/1], Loss: 0.0844, Accuracy: 98.00%
# Epoch [30/100], Step [1/1], Loss: 0.0464, Accuracy: 99.50%
# Epoch [35/100], Step [1/1], Loss: 0.0304, Accuracy: 99.50%
# Epoch [40/100], Step [1/1], Loss: 0.0227, Accuracy: 99.50%
# Epoch [45/100], Step [1/1], Loss: 0.0250, Accuracy: 99.50%
# Epoch [50/100], Step [1/1], Loss: 0.0121, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 84.42 %
# Size=200, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6238, Accuracy: 53.00%
# Epoch [10/100], Step [1/1], Loss: 0.4150, Accuracy: 88.00%
# Epoch [15/100], Step [1/1], Loss: 0.2984, Accuracy: 86.00%
# Epoch [20/100], Step [1/1], Loss: 0.2318, Accuracy: 89.00%
# Epoch [25/100], Step [1/1], Loss: 0.1650, Accuracy: 95.00%
# Epoch [30/100], Step [1/1], Loss: 0.0824, Accuracy: 98.00%
# Epoch [35/100], Step [1/1], Loss: 0.0833, Accuracy: 98.50%
# Epoch [40/100], Step [1/1], Loss: 0.0343, Accuracy: 100.00%
# Epoch [45/100], Step [1/1], Loss: 0.0328, Accuracy: 99.50%
# Epoch [50/100], Step [1/1], Loss: 0.0164, Accuracy: 100.00%
# Epoch [55/100], Step [1/1], Loss: 0.0258, Accuracy: 99.00%
# Epoch [60/100], Step [1/1], Loss: 0.0091, Accuracy: 100.00%
# Epoch [65/100], Step [1/1], Loss: 0.0123, Accuracy: 99.50%
# Epoch [70/100], Step [1/1], Loss: 0.0042, Accuracy: 100.00%
# Epoch [75/100], Step [1/1], Loss: 0.0067, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 84.96000000000001 %
# Size=400, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.4661, Accuracy: 85.75%
# Epoch [10/100], Step [1/1], Loss: 0.4469, Accuracy: 77.75%
# Epoch [15/100], Step [1/1], Loss: 0.3346, Accuracy: 86.75%
# Epoch [20/100], Step [1/1], Loss: 0.2635, Accuracy: 89.00%
# Epoch [25/100], Step [1/1], Loss: 0.2125, Accuracy: 91.00%
# Epoch [30/100], Step [1/1], Loss: 0.1822, Accuracy: 90.75%
# Epoch [35/100], Step [1/1], Loss: 0.1437, Accuracy: 94.50%
# Epoch [40/100], Step [1/1], Loss: 0.1220, Accuracy: 96.00%
# Epoch [45/100], Step [1/1], Loss: 0.0963, Accuracy: 96.50%
# Epoch [50/100], Step [1/1], Loss: 0.0596, Accuracy: 98.50%
# Epoch [55/100], Step [1/1], Loss: 0.0406, Accuracy: 99.00%
# Epoch [60/100], Step [1/1], Loss: 0.0325, Accuracy: 99.75%
# Epoch [65/100], Step [1/1], Loss: 0.0262, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 84.31 %
# Size=400, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.6314, Accuracy: 52.75%
# Epoch [10/100], Step [1/1], Loss: 0.5126, Accuracy: 77.75%
# Epoch [15/100], Step [1/1], Loss: 0.3408, Accuracy: 86.75%
# Epoch [20/100], Step [1/1], Loss: 0.3194, Accuracy: 86.75%
# Epoch [25/100], Step [1/1], Loss: 0.2756, Accuracy: 89.00%
# Epoch [30/100], Step [1/1], Loss: 0.2377, Accuracy: 90.50%
# Epoch [35/100], Step [1/1], Loss: 0.2105, Accuracy: 92.50%
# Epoch [40/100], Step [1/1], Loss: 0.1883, Accuracy: 92.50%
# Epoch [45/100], Step [1/1], Loss: 0.1355, Accuracy: 96.25%
# Epoch [50/100], Step [1/1], Loss: 0.1037, Accuracy: 97.50%
# Epoch [55/100], Step [1/1], Loss: 0.0889, Accuracy: 98.00%
# Epoch [60/100], Step [1/1], Loss: 0.0713, Accuracy: 98.25%
# Epoch [65/100], Step [1/1], Loss: 0.0538, Accuracy: 99.00%
# Epoch [70/100], Step [1/1], Loss: 0.0445, Accuracy: 98.75%
# Epoch [75/100], Step [1/1], Loss: 0.0396, Accuracy: 99.00%
# Test Accuracy of the model on the test images: 84.54 %
# Size=400, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.5613, Accuracy: 64.25%
# Epoch [10/100], Step [1/1], Loss: 0.4272, Accuracy: 82.25%
# Epoch [15/100], Step [1/1], Loss: 0.3169, Accuracy: 85.50%
# Epoch [20/100], Step [1/1], Loss: 0.2604, Accuracy: 88.75%
# Epoch [25/100], Step [1/1], Loss: 0.2254, Accuracy: 90.50%
# Epoch [30/100], Step [1/1], Loss: 0.1929, Accuracy: 91.75%
# Epoch [35/100], Step [1/1], Loss: 0.1553, Accuracy: 94.25%
# Epoch [40/100], Step [1/1], Loss: 0.1209, Accuracy: 96.00%
# Epoch [45/100], Step [1/1], Loss: 0.0732, Accuracy: 98.25%
# Epoch [50/100], Step [1/1], Loss: 0.0633, Accuracy: 98.25%
# Epoch [55/100], Step [1/1], Loss: 0.0342, Accuracy: 99.25%
# Epoch [60/100], Step [1/1], Loss: 0.0292, Accuracy: 99.25%
# Epoch [65/100], Step [1/1], Loss: 0.0273, Accuracy: 99.75%
# Epoch [70/100], Step [1/1], Loss: 0.0209, Accuracy: 99.50%
# Epoch [75/100], Step [1/1], Loss: 0.0173, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 85.52 %
# Size=400, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.5149, Accuracy: 70.00%
# Epoch [10/100], Step [1/1], Loss: 0.3045, Accuracy: 87.25%
# Epoch [15/100], Step [1/1], Loss: 0.2892, Accuracy: 87.25%
# Epoch [20/100], Step [1/1], Loss: 0.2279, Accuracy: 90.25%
# Epoch [25/100], Step [1/1], Loss: 0.2146, Accuracy: 90.00%
# Epoch [30/100], Step [1/1], Loss: 0.1499, Accuracy: 94.75%
# Epoch [35/100], Step [1/1], Loss: 0.1160, Accuracy: 95.50%
# Epoch [40/100], Step [1/1], Loss: 0.0890, Accuracy: 97.00%
# Epoch [45/100], Step [1/1], Loss: 0.0731, Accuracy: 97.50%
# Epoch [50/100], Step [1/1], Loss: 0.0477, Accuracy: 98.75%
# Epoch [55/100], Step [1/1], Loss: 0.0425, Accuracy: 99.25%
# Epoch [60/100], Step [1/1], Loss: 0.0222, Accuracy: 100.00%
# Epoch [65/100], Step [1/1], Loss: 0.0155, Accuracy: 99.75%
# Epoch [70/100], Step [1/1], Loss: 0.0163, Accuracy: 99.75%
# Epoch [75/100], Step [1/1], Loss: 0.0066, Accuracy: 100.00%
# Epoch [80/100], Step [1/1], Loss: 0.0146, Accuracy: 99.50%
# Test Accuracy of the model on the test images: 85.11999999999999 %
# Size=400, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6172, Accuracy: 55.00%
# Epoch [10/100], Step [1/1], Loss: 0.4771, Accuracy: 81.25%
# Epoch [15/100], Step [1/1], Loss: 0.3199, Accuracy: 85.00%
# Epoch [20/100], Step [1/1], Loss: 0.3088, Accuracy: 85.50%
# Epoch [25/100], Step [1/1], Loss: 0.2782, Accuracy: 87.50%
# Epoch [30/100], Step [1/1], Loss: 0.2413, Accuracy: 90.50%
# Epoch [35/100], Step [1/1], Loss: 0.2026, Accuracy: 91.75%
# Epoch [40/100], Step [1/1], Loss: 0.1643, Accuracy: 94.50%
# Epoch [45/100], Step [1/1], Loss: 0.1364, Accuracy: 96.50%
# Epoch [50/100], Step [1/1], Loss: 0.1285, Accuracy: 95.00%
# Epoch [55/100], Step [1/1], Loss: 0.0926, Accuracy: 97.25%
# Epoch [60/100], Step [1/1], Loss: 0.0674, Accuracy: 98.50%
# Epoch [65/100], Step [1/1], Loss: 0.0697, Accuracy: 97.25%
# Epoch [70/100], Step [1/1], Loss: 0.0482, Accuracy: 99.25%
# Epoch [75/100], Step [1/1], Loss: 0.0450, Accuracy: 98.50%
# Epoch [80/100], Step [1/1], Loss: 0.0274, Accuracy: 99.50%
# Epoch [85/100], Step [1/1], Loss: 0.0319, Accuracy: 99.00%
# Epoch [90/100], Step [1/1], Loss: 0.0315, Accuracy: 98.50%
# Epoch [95/100], Step [1/1], Loss: 0.0223, Accuracy: 100.00%
# Epoch [100/100], Step [1/1], Loss: 0.0213, Accuracy: 99.25%
# Test Accuracy of the model on the test images: 85.28 %
# Size=1000, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.5270, Accuracy: 83.80%
# Epoch [10/100], Step [1/1], Loss: 0.4011, Accuracy: 84.70%
# Epoch [15/100], Step [1/1], Loss: 0.3372, Accuracy: 85.00%
# Epoch [20/100], Step [1/1], Loss: 0.3178, Accuracy: 86.60%
# Epoch [25/100], Step [1/1], Loss: 0.2854, Accuracy: 87.70%
# Epoch [30/100], Step [1/1], Loss: 0.2740, Accuracy: 88.20%
# Epoch [35/100], Step [1/1], Loss: 0.2405, Accuracy: 90.00%
# Epoch [40/100], Step [1/1], Loss: 0.2391, Accuracy: 90.00%
# Epoch [45/100], Step [1/1], Loss: 0.2059, Accuracy: 91.10%
# Epoch [50/100], Step [1/1], Loss: 0.1855, Accuracy: 93.00%
# Epoch [55/100], Step [1/1], Loss: 0.1678, Accuracy: 93.30%
# Epoch [60/100], Step [1/1], Loss: 0.1382, Accuracy: 95.50%
# Epoch [65/100], Step [1/1], Loss: 0.1298, Accuracy: 94.70%
# Epoch [70/100], Step [1/1], Loss: 0.1022, Accuracy: 96.80%
# Epoch [75/100], Step [1/1], Loss: 0.1044, Accuracy: 97.00%
# Epoch [80/100], Step [1/1], Loss: 0.0861, Accuracy: 96.60%
# Epoch [85/100], Step [1/1], Loss: 0.0669, Accuracy: 97.70%
# Epoch [90/100], Step [1/1], Loss: 0.0595, Accuracy: 98.10%
# Epoch [95/100], Step [1/1], Loss: 0.0507, Accuracy: 98.70%
# Epoch [100/100], Step [1/1], Loss: 0.0518, Accuracy: 98.10%
# Test Accuracy of the model on the test images: 84.82 %
# Size=1000, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.5638, Accuracy: 74.40%
# Epoch [10/100], Step [1/1], Loss: 0.4003, Accuracy: 84.90%
# Epoch [15/100], Step [1/1], Loss: 0.3466, Accuracy: 85.20%
# Epoch [20/100], Step [1/1], Loss: 0.3234, Accuracy: 86.20%
# Epoch [25/100], Step [1/1], Loss: 0.2864, Accuracy: 86.40%
# Epoch [30/100], Step [1/1], Loss: 0.2925, Accuracy: 87.60%
# Epoch [35/100], Step [1/1], Loss: 0.2607, Accuracy: 88.80%
# Epoch [40/100], Step [1/1], Loss: 0.2499, Accuracy: 88.60%
# Epoch [45/100], Step [1/1], Loss: 0.2309, Accuracy: 90.20%
# Epoch [50/100], Step [1/1], Loss: 0.1869, Accuracy: 92.90%
# Epoch [55/100], Step [1/1], Loss: 0.1735, Accuracy: 93.10%
# Epoch [60/100], Step [1/1], Loss: 0.1531, Accuracy: 93.90%
# Epoch [65/100], Step [1/1], Loss: 0.1243, Accuracy: 95.70%
# Epoch [70/100], Step [1/1], Loss: 0.1184, Accuracy: 95.70%
# Epoch [75/100], Step [1/1], Loss: 0.1123, Accuracy: 95.60%
# Epoch [80/100], Step [1/1], Loss: 0.0794, Accuracy: 97.50%
# Epoch [85/100], Step [1/1], Loss: 0.0744, Accuracy: 97.30%
# Test Accuracy of the model on the test images: 85.1 %
# Size=1000, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.6083, Accuracy: 66.90%
# Epoch [10/100], Step [1/1], Loss: 0.5261, Accuracy: 79.40%
# Epoch [15/100], Step [1/1], Loss: 0.3799, Accuracy: 83.50%
# Epoch [20/100], Step [1/1], Loss: 0.3346, Accuracy: 85.20%
# Epoch [25/100], Step [1/1], Loss: 0.3167, Accuracy: 87.10%
# Epoch [30/100], Step [1/1], Loss: 0.2999, Accuracy: 86.90%
# Epoch [35/100], Step [1/1], Loss: 0.2758, Accuracy: 88.60%
# Epoch [40/100], Step [1/1], Loss: 0.2580, Accuracy: 89.70%
# Epoch [45/100], Step [1/1], Loss: 0.2410, Accuracy: 90.80%
# Epoch [50/100], Step [1/1], Loss: 0.2267, Accuracy: 90.20%
# Epoch [55/100], Step [1/1], Loss: 0.2088, Accuracy: 91.20%
# Epoch [60/100], Step [1/1], Loss: 0.1910, Accuracy: 93.00%
# Epoch [65/100], Step [1/1], Loss: 0.1807, Accuracy: 93.10%
# Epoch [70/100], Step [1/1], Loss: 0.1569, Accuracy: 94.50%
# Test Accuracy of the model on the test images: 85.5 %
# Size=1000, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.7481, Accuracy: 50.00%
# Epoch [10/100], Step [1/1], Loss: 0.6060, Accuracy: 70.30%
# Epoch [15/100], Step [1/1], Loss: 0.4795, Accuracy: 80.40%
# Epoch [20/100], Step [1/1], Loss: 0.3657, Accuracy: 83.10%
# Epoch [25/100], Step [1/1], Loss: 0.3512, Accuracy: 84.00%
# Epoch [30/100], Step [1/1], Loss: 0.3258, Accuracy: 86.20%
# Epoch [35/100], Step [1/1], Loss: 0.3303, Accuracy: 85.20%
# Epoch [40/100], Step [1/1], Loss: 0.3013, Accuracy: 86.60%
# Epoch [45/100], Step [1/1], Loss: 0.2918, Accuracy: 88.10%
# Epoch [50/100], Step [1/1], Loss: 0.2849, Accuracy: 87.00%
# Epoch [55/100], Step [1/1], Loss: 0.2660, Accuracy: 88.50%
# Epoch [60/100], Step [1/1], Loss: 0.2743, Accuracy: 88.70%
# Epoch [65/100], Step [1/1], Loss: 0.2503, Accuracy: 88.60%
# Epoch [70/100], Step [1/1], Loss: 0.2310, Accuracy: 90.10%
# Epoch [75/100], Step [1/1], Loss: 0.2181, Accuracy: 90.80%
# Epoch [80/100], Step [1/1], Loss: 0.2003, Accuracy: 91.90%
# Epoch [85/100], Step [1/1], Loss: 0.1817, Accuracy: 92.60%
# Epoch [90/100], Step [1/1], Loss: 0.1735, Accuracy: 93.00%
# Epoch [95/100], Step [1/1], Loss: 0.1523, Accuracy: 94.10%
# Epoch [100/100], Step [1/1], Loss: 0.1317, Accuracy: 95.20%
# Test Accuracy of the model on the test images: 85.34 %
# Size=1000, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.6670, Accuracy: 50.00%
# Epoch [10/100], Step [1/1], Loss: 0.5607, Accuracy: 81.50%
# Epoch [15/100], Step [1/1], Loss: 0.3744, Accuracy: 84.90%
# Epoch [20/100], Step [1/1], Loss: 0.3518, Accuracy: 84.70%
# Epoch [25/100], Step [1/1], Loss: 0.3381, Accuracy: 85.80%
# Epoch [30/100], Step [1/1], Loss: 0.3063, Accuracy: 87.30%
# Epoch [35/100], Step [1/1], Loss: 0.2900, Accuracy: 87.20%
# Test Accuracy of the model on the test images: 86.36 %
# Size=2000, Iterate 1
# Epoch [5/100], Step [1/1], Loss: 0.5417, Accuracy: 73.60%
# Epoch [10/100], Step [1/1], Loss: 0.4261, Accuracy: 80.95%
# Epoch [15/100], Step [1/1], Loss: 0.3252, Accuracy: 85.80%
# Epoch [20/100], Step [1/1], Loss: 0.3457, Accuracy: 85.70%
# Epoch [25/100], Step [1/1], Loss: 0.3047, Accuracy: 87.10%
# Epoch [30/100], Step [1/1], Loss: 0.2890, Accuracy: 87.40%
# Epoch [35/100], Step [1/1], Loss: 0.2854, Accuracy: 87.70%
# Epoch [40/100], Step [1/1], Loss: 0.2630, Accuracy: 88.50%
# Epoch [45/100], Step [1/1], Loss: 0.2715, Accuracy: 88.40%
# Epoch [50/100], Step [1/1], Loss: 0.2501, Accuracy: 89.35%
# Epoch [55/100], Step [1/1], Loss: 0.2403, Accuracy: 90.35%
# Test Accuracy of the model on the test images: 86.61 %
# Size=2000, Iterate 2
# Epoch [5/100], Step [1/1], Loss: 0.5659, Accuracy: 66.20%
# Epoch [10/100], Step [1/1], Loss: 0.4641, Accuracy: 80.95%
# Epoch [15/100], Step [1/1], Loss: 0.3593, Accuracy: 83.95%
# Epoch [20/100], Step [1/1], Loss: 0.3281, Accuracy: 85.90%
# Epoch [25/100], Step [1/1], Loss: 0.3194, Accuracy: 86.05%
# Epoch [30/100], Step [1/1], Loss: 0.2880, Accuracy: 88.05%
# Epoch [35/100], Step [1/1], Loss: 0.2837, Accuracy: 87.90%
# Test Accuracy of the model on the test images: 86.57000000000001 %
# Size=2000, Iterate 3
# Epoch [5/100], Step [1/1], Loss: 0.7103, Accuracy: 50.00%
# Epoch [10/100], Step [1/1], Loss: 0.5939, Accuracy: 80.85%
# Epoch [15/100], Step [1/1], Loss: 0.4738, Accuracy: 81.40%
# Epoch [20/100], Step [1/1], Loss: 0.3609, Accuracy: 84.20%
# Epoch [25/100], Step [1/1], Loss: 0.3584, Accuracy: 84.50%
# Epoch [30/100], Step [1/1], Loss: 0.3443, Accuracy: 85.25%
# Epoch [35/100], Step [1/1], Loss: 0.3189, Accuracy: 86.25%
# Epoch [40/100], Step [1/1], Loss: 0.3091, Accuracy: 86.45%
# Epoch [45/100], Step [1/1], Loss: 0.2969, Accuracy: 87.55%
# Epoch [50/100], Step [1/1], Loss: 0.2946, Accuracy: 86.90%
# Epoch [55/100], Step [1/1], Loss: 0.2768, Accuracy: 88.20%
# Epoch [60/100], Step [1/1], Loss: 0.2768, Accuracy: 88.25%
# Epoch [65/100], Step [1/1], Loss: 0.2663, Accuracy: 88.70%
# Epoch [70/100], Step [1/1], Loss: 0.2682, Accuracy: 88.70%
# Test Accuracy of the model on the test images: 86.7 %
# Size=2000, Iterate 4
# Epoch [5/100], Step [1/1], Loss: 0.6658, Accuracy: 51.80%
# Epoch [10/100], Step [1/1], Loss: 0.5169, Accuracy: 77.05%
# Epoch [15/100], Step [1/1], Loss: 0.3922, Accuracy: 83.80%
# Epoch [20/100], Step [1/1], Loss: 0.3335, Accuracy: 85.45%
# Epoch [25/100], Step [1/1], Loss: 0.3258, Accuracy: 86.00%
# Epoch [30/100], Step [1/1], Loss: 0.3103, Accuracy: 86.80%
# Epoch [35/100], Step [1/1], Loss: 0.2962, Accuracy: 87.15%
# Epoch [40/100], Step [1/1], Loss: 0.2869, Accuracy: 87.30%
# Test Accuracy of the model on the test images: 86.7 %
# Size=2000, Iterate 5
# Epoch [5/100], Step [1/1], Loss: 0.7542, Accuracy: 50.00%
# Epoch [10/100], Step [1/1], Loss: 0.6196, Accuracy: 79.15%
# Epoch [15/100], Step [1/1], Loss: 0.4991, Accuracy: 81.10%
# Epoch [20/100], Step [1/1], Loss: 0.3790, Accuracy: 83.25%
# Epoch [25/100], Step [1/1], Loss: 0.3629, Accuracy: 84.65%
# Epoch [30/100], Step [1/1], Loss: 0.3399, Accuracy: 85.80%
# Epoch [35/100], Step [1/1], Loss: 0.3307, Accuracy: 85.70%
# Epoch [40/100], Step [1/1], Loss: 0.3120, Accuracy: 85.90%
# Epoch [45/100], Step [1/1], Loss: 0.3053, Accuracy: 87.00%
# Epoch [50/100], Step [1/1], Loss: 0.2959, Accuracy: 87.45%
# Epoch [55/100], Step [1/1], Loss: 0.2902, Accuracy: 87.25%
# Test Accuracy of the model on the test images: 86.72 %
